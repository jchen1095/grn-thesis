# %% [markdown]
# # Pipeline for Simulating GRNS on Sergio & Packing into Anndata object
#
# First, create the files

# %% [markdown]
# Import the necessary modules

# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
from pyslingshot import Slingshot #for simulating pseudotimes
import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../SERGIO'))
from SERGIO.sergio import sergio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Simulate the GRN and save the splicing data to files

# %%
df = pd.read_csv('experiments_final/num_6/perturbed_matrix.tab', sep='\t', header=None, index_col=None)
bMat = df.values
print('here')
#rows and cols correspond to genes and cells (just verify)
# 100 x (6 x 300 )
#  100 genes, 6 cell types, 6 bins of 300 cells per cell type
# DO NOT include MR in the gene count
# make sure that all cells are tab separated and that zeros are just 0
# genes that are ONLY affector genes in the grn MUST be included as MR in the MR file
sim = sergio(number_genes=10, number_bins = 4, number_sc = 300, noise_params = 0.2, decays=0.8, sampling_state = 1, noise_params_splice = 0.07, noise_type='dpd', dynamics=True, bifurcation_matrix= bMat)
sim.build_graph(input_file_taregts ='experiments_final/num_6/gene_interactions.txt', input_file_regs='experiments_final/num_6/master_regulators.txt', shared_coop_state=2)
sim.simulate_dynamics()
# final ct matrix is the sum of U and S
#spliced matrix, unspliced, sum of both, pseudotime (probs just a vector bc each element in pseudotime is 1d scalar for 1 cell)
exprU, exprS = sim.getExpressions_dynamics()
exprU_clean = np.concatenate(exprU, axis = 1)
print(exprU_clean)
print(exprU_clean.shape)

exprS_clean = np.concatenate(exprS, axis = 1)
print(f"exprU_clean shape: {exprU_clean.shape}")
print(f"exprS_clean shape: {exprS_clean.shape}")

# Print the number of columns for each row
for i, row in enumerate(exprU_clean):
    print(f"Row {i} of exprU_clean has {len(row)} columns")

for i, row in enumerate(exprS_clean):
    print(f"Row {i} of exprS_clean has {len(row)} columns")

# Optionally save to text files
np.savetxt('exprU_clean.txt', exprU_clean, delimiter=' ', fmt='%f')
np.savetxt('exprS_clean.txt', exprS_clean, delimiter=' ', fmt='%f')
# Out:
# here
# bindict
#
# === Starting bin 0 ===
#
# === Starting simulation for binID: 0 ===
# Number of initial cells: 15
#
#
# --- Iteration step: 0 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6767
# prod_rate_S mean: 0.6767, decay_S mean: 0.6790
#
# Simulating gene 1
# prod_rate_U mean: 0.6922, decay_U mean: 0.6913
# prod_rate_S mean: 0.6913, decay_S mean: 0.6996
#
# Simulating gene 2
# prod_rate_U mean: 0.9459, decay_U mean: 0.9470
# prod_rate_S mean: 0.9470, decay_S mean: 0.9259
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4034
# prod_rate_S mean: 1.4034, decay_S mean: 1.3736
#
# Simulating gene 4
# prod_rate_U mean: 2.2958, decay_U mean: 2.3198
# prod_rate_S mean: 2.3198, decay_S mean: 2.3210
#
# Simulating gene 5
# prod_rate_U mean: 0.9476, decay_U mean: 0.9666
# prod_rate_S mean: 0.9666, decay_S mean: 0.9753
#
# Simulating gene 6
# prod_rate_U mean: 2.5617, decay_U mean: 2.5484
# prod_rate_S mean: 2.5484, decay_S mean: 2.5409
#
# Simulating gene 7
# prod_rate_U mean: 1.1152, decay_U mean: 1.1111
# prod_rate_S mean: 1.1111, decay_S mean: 1.1120
#
# Simulating gene 8
# prod_rate_U mean: 2.5007, decay_U mean: 2.4858
# prod_rate_S mean: 2.4858, decay_S mean: 2.5477
#
# Simulating gene 9
# prod_rate_U mean: 2.9373, decay_U mean: 2.9546
# prod_rate_S mean: 2.9546, decay_S mean: 2.9970
# Step 0: Converged = False
#
# --- Iteration step: 1 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6738
# prod_rate_S mean: 0.6738, decay_S mean: 0.6794
#
# Simulating gene 1
# prod_rate_U mean: 0.6875, decay_U mean: 0.6848
# prod_rate_S mean: 0.6848, decay_S mean: 0.6999
#
# Simulating gene 2
# prod_rate_U mean: 0.9455, decay_U mean: 0.9531
# prod_rate_S mean: 0.9531, decay_S mean: 0.9271
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.3971
# prod_rate_S mean: 1.3971, decay_S mean: 1.3735
#
# Simulating gene 4
# prod_rate_U mean: 2.3065, decay_U mean: 2.3219
# prod_rate_S mean: 2.3219, decay_S mean: 2.3211
#
# Simulating gene 5
# prod_rate_U mean: 0.9492, decay_U mean: 0.9628
# prod_rate_S mean: 0.9628, decay_S mean: 0.9750
#
# Simulating gene 6
# prod_rate_U mean: 2.5531, decay_U mean: 2.5638
# prod_rate_S mean: 2.5638, decay_S mean: 2.5412
#
# Simulating gene 7
# prod_rate_U mean: 1.1105, decay_U mean: 1.1175
# prod_rate_S mean: 1.1175, decay_S mean: 1.1112
#
# Simulating gene 8
# prod_rate_U mean: 2.5038, decay_U mean: 2.4959
# prod_rate_S mean: 2.4959, decay_S mean: 2.5474
#
# Simulating gene 9
# prod_rate_U mean: 2.9498, decay_U mean: 2.9601
# prod_rate_S mean: 2.9601, decay_S mean: 2.9971
# Step 1: Converged = False
#
# --- Iteration step: 2 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6700
# prod_rate_S mean: 0.6700, decay_S mean: 0.6789
#
# Simulating gene 1
# prod_rate_U mean: 0.6903, decay_U mean: 0.6854
# prod_rate_S mean: 0.6854, decay_S mean: 0.7004
#
# Simulating gene 2
# prod_rate_U mean: 0.9444, decay_U mean: 0.9499
# prod_rate_S mean: 0.9499, decay_S mean: 0.9275
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4009
# prod_rate_S mean: 1.4009, decay_S mean: 1.3738
#
# Simulating gene 4
# prod_rate_U mean: 2.3090, decay_U mean: 2.3131
# prod_rate_S mean: 2.3131, decay_S mean: 2.3216
#
# Simulating gene 5
# prod_rate_U mean: 0.9455, decay_U mean: 0.9582
# prod_rate_S mean: 0.9582, decay_S mean: 0.9746
#
# Simulating gene 6
# prod_rate_U mean: 2.5530, decay_U mean: 2.5696
# prod_rate_S mean: 2.5696, decay_S mean: 2.5415
#
# Simulating gene 7
# prod_rate_U mean: 1.1180, decay_U mean: 1.1253
# prod_rate_S mean: 1.1253, decay_S mean: 1.1117
#
# Simulating gene 8
# prod_rate_U mean: 2.5011, decay_U mean: 2.5115
# prod_rate_S mean: 2.5115, decay_S mean: 2.5472
#
# Simulating gene 9
# prod_rate_U mean: 2.9434, decay_U mean: 2.9561
# prod_rate_S mean: 2.9561, decay_S mean: 2.9971
# Step 2: Converged = False
#
# --- Iteration step: 3 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6787
# prod_rate_S mean: 0.6787, decay_S mean: 0.6792
#
# Simulating gene 1
# prod_rate_U mean: 0.6874, decay_U mean: 0.6873
# prod_rate_S mean: 0.6873, decay_S mean: 0.7002
#
# Simulating gene 2
# prod_rate_U mean: 0.9425, decay_U mean: 0.9446
# prod_rate_S mean: 0.9446, decay_S mean: 0.9275
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.3970
# prod_rate_S mean: 1.3970, decay_S mean: 1.3751
#
# Simulating gene 4
# prod_rate_U mean: 2.3202, decay_U mean: 2.3327
# prod_rate_S mean: 2.3327, decay_S mean: 2.3210
#
# Simulating gene 5
# prod_rate_U mean: 0.9451, decay_U mean: 0.9581
# prod_rate_S mean: 0.9581, decay_S mean: 0.9742
#
# Simulating gene 6
# prod_rate_U mean: 2.5420, decay_U mean: 2.5660
# prod_rate_S mean: 2.5660, decay_S mean: 2.5418
#
# Simulating gene 7
# prod_rate_U mean: 1.1106, decay_U mean: 1.1297
# prod_rate_S mean: 1.1297, decay_S mean: 1.1124
#
# Simulating gene 8
# prod_rate_U mean: 2.5067, decay_U mean: 2.5050
# prod_rate_S mean: 2.5050, decay_S mean: 2.5473
#
# Simulating gene 9
# prod_rate_U mean: 2.9456, decay_U mean: 2.9637
# prod_rate_S mean: 2.9637, decay_S mean: 2.9968
# Step 3: Converged = False
#
# --- Iteration step: 4 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6733
# prod_rate_S mean: 0.6733, decay_S mean: 0.6794
#
# Simulating gene 1
# prod_rate_U mean: 0.6946, decay_U mean: 0.6906
# prod_rate_S mean: 0.6906, decay_S mean: 0.7000
#
# Simulating gene 2
# prod_rate_U mean: 0.9398, decay_U mean: 0.9453
# prod_rate_S mean: 0.9453, decay_S mean: 0.9282
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4066
# prod_rate_S mean: 1.4066, decay_S mean: 1.3748
#
# Simulating gene 4
# prod_rate_U mean: 2.3255, decay_U mean: 2.3348
# prod_rate_S mean: 2.3348, decay_S mean: 2.3213
#
# Simulating gene 5
# prod_rate_U mean: 0.9472, decay_U mean: 0.9514
# prod_rate_S mean: 0.9514, decay_S mean: 0.9748
#
# Simulating gene 6
# prod_rate_U mean: 2.5322, decay_U mean: 2.5748
# prod_rate_S mean: 2.5748, decay_S mean: 2.5427
#
# Simulating gene 7
# prod_rate_U mean: 1.1113, decay_U mean: 1.1264
# prod_rate_S mean: 1.1264, decay_S mean: 1.1126
#
# Simulating gene 8
# prod_rate_U mean: 2.5081, decay_U mean: 2.5069
# prod_rate_S mean: 2.5069, decay_S mean: 2.5478
#
# Simulating gene 9
# prod_rate_U mean: 2.9411, decay_U mean: 2.9834
# prod_rate_S mean: 2.9834, decay_S mean: 2.9972
# Step 4: Converged = False
#
# --- Iteration step: 5 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6758
# prod_rate_S mean: 0.6758, decay_S mean: 0.6796
#
# Simulating gene 1
# prod_rate_U mean: 0.6956, decay_U mean: 0.6953
# prod_rate_S mean: 0.6953, decay_S mean: 0.7001
#
# Simulating gene 2
# prod_rate_U mean: 0.9440, decay_U mean: 0.9425
# prod_rate_S mean: 0.9425, decay_S mean: 0.9272
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4080
# prod_rate_S mean: 1.4080, decay_S mean: 1.3745
#
# Simulating gene 4
# prod_rate_U mean: 2.3201, decay_U mean: 2.3239
# prod_rate_S mean: 2.3239, decay_S mean: 2.3219
#
# Simulating gene 5
# prod_rate_U mean: 0.9491, decay_U mean: 0.9455
# prod_rate_S mean: 0.9455, decay_S mean: 0.9753
#
# Simulating gene 6
# prod_rate_U mean: 2.5287, decay_U mean: 2.5778
# prod_rate_S mean: 2.5778, decay_S mean: 2.5417
#
# Simulating gene 7
# prod_rate_U mean: 1.1076, decay_U mean: 1.1289
# prod_rate_S mean: 1.1289, decay_S mean: 1.1126
#
# Simulating gene 8
# prod_rate_U mean: 2.5111, decay_U mean: 2.5007
# prod_rate_S mean: 2.5007, decay_S mean: 2.5482
#
# Simulating gene 9
# prod_rate_U mean: 2.9485, decay_U mean: 2.9870
# prod_rate_S mean: 2.9870, decay_S mean: 2.9969
# Step 5: Converged = False
#
# --- Iteration step: 6 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6734
# prod_rate_S mean: 0.6734, decay_S mean: 0.6791
#
# Simulating gene 1
# prod_rate_U mean: 0.6948, decay_U mean: 0.6876
# prod_rate_S mean: 0.6876, decay_S mean: 0.6997
#
# Simulating gene 2
# prod_rate_U mean: 0.9441, decay_U mean: 0.9454
# prod_rate_S mean: 0.9454, decay_S mean: 0.9280
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4069
# prod_rate_S mean: 1.4069, decay_S mean: 1.3750
#
# Simulating gene 4
# prod_rate_U mean: 2.3281, decay_U mean: 2.3138
# prod_rate_S mean: 2.3138, decay_S mean: 2.3220
#
# Simulating gene 5
# prod_rate_U mean: 0.9498, decay_U mean: 0.9446
# prod_rate_S mean: 0.9446, decay_S mean: 0.9752
#
# Simulating gene 6
# prod_rate_U mean: 2.5233, decay_U mean: 2.5829
# prod_rate_S mean: 2.5829, decay_S mean: 2.5417
#
# Simulating gene 7
# prod_rate_U mean: 1.1052, decay_U mean: 1.1387
# prod_rate_S mean: 1.1387, decay_S mean: 1.1127
#
# Simulating gene 8
# prod_rate_U mean: 2.5131, decay_U mean: 2.5107
# prod_rate_S mean: 2.5107, decay_S mean: 2.5481
#
# Simulating gene 9
# prod_rate_U mean: 2.9491, decay_U mean: 2.9797
# prod_rate_S mean: 2.9797, decay_S mean: 2.9984
# Step 6: Converged = False
#
# --- Iteration step: 7 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6724
# prod_rate_S mean: 0.6724, decay_S mean: 0.6791
#
# Simulating gene 1
# prod_rate_U mean: 0.6835, decay_U mean: 0.6874
# prod_rate_S mean: 0.6874, decay_S mean: 0.7006
#
# Simulating gene 2
# prod_rate_U mean: 0.9478, decay_U mean: 0.9297
# prod_rate_S mean: 0.9297, decay_S mean: 0.9283
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.3917
# prod_rate_S mean: 1.3917, decay_S mean: 1.3748
#
# Simulating gene 4
# prod_rate_U mean: 2.3032, decay_U mean: 2.3101
# prod_rate_S mean: 2.3101, decay_S mean: 2.3231
#
# Simulating gene 5
# prod_rate_U mean: 0.9522, decay_U mean: 0.9413
# prod_rate_S mean: 0.9413, decay_S mean: 0.9747
#
# Simulating gene 6
# prod_rate_U mean: 2.5207, decay_U mean: 2.5864
# prod_rate_S mean: 2.5864, decay_S mean: 2.5408
#
# Simulating gene 7
# prod_rate_U mean: 1.0977, decay_U mean: 1.1394
# prod_rate_S mean: 1.1394, decay_S mean: 1.1131
#
# Simulating gene 8
# prod_rate_U mean: 2.5114, decay_U mean: 2.5112
# prod_rate_S mean: 2.5112, decay_S mean: 2.5476
#
# Simulating gene 9
# prod_rate_U mean: 2.9593, decay_U mean: 2.9696
# prod_rate_S mean: 2.9696, decay_S mean: 2.9981
# Step 7: Converged = False
#
# --- Iteration step: 8 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6580
# prod_rate_S mean: 0.6580, decay_S mean: 0.6787
#
# Simulating gene 1
# prod_rate_U mean: 0.6721, decay_U mean: 0.6808
# prod_rate_S mean: 0.6808, decay_S mean: 0.6997
#
# Simulating gene 2
# prod_rate_U mean: 0.9436, decay_U mean: 0.9323
# prod_rate_S mean: 0.9323, decay_S mean: 0.9281
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.3764
# prod_rate_S mean: 1.3764, decay_S mean: 1.3750
#
# Simulating gene 4
# prod_rate_U mean: 2.3210, decay_U mean: 2.2969
# prod_rate_S mean: 2.2969, decay_S mean: 2.3233
#
# Simulating gene 5
# prod_rate_U mean: 0.9534, decay_U mean: 0.9402
# prod_rate_S mean: 0.9402, decay_S mean: 0.9748
#
# Simulating gene 6
# prod_rate_U mean: 2.5231, decay_U mean: 2.5836
# prod_rate_S mean: 2.5836, decay_S mean: 2.5408
#
# Simulating gene 7
# prod_rate_U mean: 1.1017, decay_U mean: 1.1254
# prod_rate_S mean: 1.1254, decay_S mean: 1.1129
#
# Simulating gene 8
# prod_rate_U mean: 2.5090, decay_U mean: 2.5247
# prod_rate_S mean: 2.5247, decay_S mean: 2.5469
#
# Simulating gene 9
# prod_rate_U mean: 2.9521, decay_U mean: 2.9845
# prod_rate_S mean: 2.9845, decay_S mean: 2.9970
# Step 8: Converged = False
#
# --- Iteration step: 9 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6616
# prod_rate_S mean: 0.6616, decay_S mean: 0.6784
#
# Simulating gene 1
# prod_rate_U mean: 0.6746, decay_U mean: 0.6882
# prod_rate_S mean: 0.6882, decay_S mean: 0.7001
#
# Simulating gene 2
# prod_rate_U mean: 0.9475, decay_U mean: 0.9242
# prod_rate_S mean: 0.9242, decay_S mean: 0.9280
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.3798
# prod_rate_S mean: 1.3798, decay_S mean: 1.3757
#
# Simulating gene 4
# prod_rate_U mean: 2.3322, decay_U mean: 2.2905
# prod_rate_S mean: 2.2905, decay_S mean: 2.3237
#
# Simulating gene 5
# prod_rate_U mean: 0.9557, decay_U mean: 0.9414
# prod_rate_S mean: 0.9414, decay_S mean: 0.9753
#
# Simulating gene 6
# prod_rate_U mean: 2.5404, decay_U mean: 2.5802
# prod_rate_S mean: 2.5802, decay_S mean: 2.5409
#
# Simulating gene 7
# prod_rate_U mean: 1.1107, decay_U mean: 1.1329
# prod_rate_S mean: 1.1329, decay_S mean: 1.1127
#
# Simulating gene 8
# prod_rate_U mean: 2.5014, decay_U mean: 2.5164
# prod_rate_S mean: 2.5164, decay_S mean: 2.5483
#
# Simulating gene 9
# prod_rate_U mean: 2.9557, decay_U mean: 2.9631
# prod_rate_S mean: 2.9631, decay_S mean: 2.9972
# Step 9: Converged = False
#
# --- Iteration step: 10 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6664
# prod_rate_S mean: 0.6664, decay_S mean: 0.6782
#
# Simulating gene 1
# prod_rate_U mean: 0.6801, decay_U mean: 0.6813
# prod_rate_S mean: 0.6813, decay_S mean: 0.7000
#
# Simulating gene 2
# prod_rate_U mean: 0.9498, decay_U mean: 0.9230
# prod_rate_S mean: 0.9230, decay_S mean: 0.9280
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.3873
# prod_rate_S mean: 1.3873, decay_S mean: 1.3754
#
# Simulating gene 4
# prod_rate_U mean: 2.3850, decay_U mean: 2.2779
# prod_rate_S mean: 2.2779, decay_S mean: 2.3229
#
# Simulating gene 5
# prod_rate_U mean: 0.9557, decay_U mean: 0.9513
# prod_rate_S mean: 0.9513, decay_S mean: 0.9756
#
# Simulating gene 6
# prod_rate_U mean: 2.5415, decay_U mean: 2.5696
# prod_rate_S mean: 2.5696, decay_S mean: 2.5410
#
# Simulating gene 7
# prod_rate_U mean: 1.1082, decay_U mean: 1.1311
# prod_rate_S mean: 1.1311, decay_S mean: 1.1120
#
# Simulating gene 8
# prod_rate_U mean: 2.5028, decay_U mean: 2.5212
# prod_rate_S mean: 2.5212, decay_S mean: 2.5474
#
# Simulating gene 9
# prod_rate_U mean: 2.9547, decay_U mean: 2.9491
# prod_rate_S mean: 2.9491, decay_S mean: 2.9979
# Step 10: Converged = False
#
# --- Iteration step: 11 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6632
# prod_rate_S mean: 0.6632, decay_S mean: 0.6779
#
# Simulating gene 1
# prod_rate_U mean: 0.6932, decay_U mean: 0.6771
# prod_rate_S mean: 0.6771, decay_S mean: 0.7007
#
# Simulating gene 2
# prod_rate_U mean: 0.9495, decay_U mean: 0.9058
# prod_rate_S mean: 0.9058, decay_S mean: 0.9285
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4048
# prod_rate_S mean: 1.4048, decay_S mean: 1.3759
#
# Simulating gene 4
# prod_rate_U mean: 2.3800, decay_U mean: 2.2778
# prod_rate_S mean: 2.2778, decay_S mean: 2.3226
#
# Simulating gene 5
# prod_rate_U mean: 0.9566, decay_U mean: 0.9526
# prod_rate_S mean: 0.9526, decay_S mean: 0.9757
#
# Simulating gene 6
# prod_rate_U mean: 2.5562, decay_U mean: 2.5719
# prod_rate_S mean: 2.5719, decay_S mean: 2.5395
#
# Simulating gene 7
# prod_rate_U mean: 1.1026, decay_U mean: 1.1280
# prod_rate_S mean: 1.1280, decay_S mean: 1.1127
#
# Simulating gene 8
# prod_rate_U mean: 2.5107, decay_U mean: 2.5196
# prod_rate_S mean: 2.5196, decay_S mean: 2.5469
#
# Simulating gene 9
# prod_rate_U mean: 2.9599, decay_U mean: 2.9375
# prod_rate_S mean: 2.9375, decay_S mean: 2.9992
# Step 11: Converged = False
#
# --- Iteration step: 12 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6635
# prod_rate_S mean: 0.6635, decay_S mean: 0.6772
#
# Simulating gene 1
# prod_rate_U mean: 0.6969, decay_U mean: 0.6777
# prod_rate_S mean: 0.6777, decay_S mean: 0.7010
#
# Simulating gene 2
# prod_rate_U mean: 0.9495, decay_U mean: 0.9135
# prod_rate_S mean: 0.9135, decay_S mean: 0.9287
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4098
# prod_rate_S mean: 1.4098, decay_S mean: 1.3769
#
# Simulating gene 4
# prod_rate_U mean: 2.3878, decay_U mean: 2.2732
# prod_rate_S mean: 2.2732, decay_S mean: 2.3220
#
# Simulating gene 5
# prod_rate_U mean: 0.9576, decay_U mean: 0.9608
# prod_rate_S mean: 0.9608, decay_S mean: 0.9758
#
# Simulating gene 6
# prod_rate_U mean: 2.5440, decay_U mean: 2.5854
# prod_rate_S mean: 2.5854, decay_S mean: 2.5402
#
# Simulating gene 7
# prod_rate_U mean: 1.0920, decay_U mean: 1.1302
# prod_rate_S mean: 1.1302, decay_S mean: 1.1120
#
# Simulating gene 8
# prod_rate_U mean: 2.5143, decay_U mean: 2.5269
# prod_rate_S mean: 2.5269, decay_S mean: 2.5446
#
# Simulating gene 9
# prod_rate_U mean: 2.9719, decay_U mean: 2.9420
# prod_rate_S mean: 2.9420, decay_S mean: 2.9996
# Step 12: Converged = False
#
# --- Iteration step: 13 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6508
# prod_rate_S mean: 0.6508, decay_S mean: 0.6775
#
# Simulating gene 1
# prod_rate_U mean: 0.6983, decay_U mean: 0.6776
# prod_rate_S mean: 0.6776, decay_S mean: 0.7012
#
# Simulating gene 2
# prod_rate_U mean: 0.9513, decay_U mean: 0.9103
# prod_rate_S mean: 0.9103, decay_S mean: 0.9290
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4117
# prod_rate_S mean: 1.4117, decay_S mean: 1.3769
#
# Simulating gene 4
# prod_rate_U mean: 2.3841, decay_U mean: 2.2676
# prod_rate_S mean: 2.2676, decay_S mean: 2.3216
#
# Simulating gene 5
# prod_rate_U mean: 0.9595, decay_U mean: 0.9543
# prod_rate_S mean: 0.9543, decay_S mean: 0.9755
#
# Simulating gene 6
# prod_rate_U mean: 2.5462, decay_U mean: 2.5921
# prod_rate_S mean: 2.5921, decay_S mean: 2.5409
#
# Simulating gene 7
# prod_rate_U mean: 1.0824, decay_U mean: 1.1314
# prod_rate_S mean: 1.1314, decay_S mean: 1.1120
#
# Simulating gene 8
# prod_rate_U mean: 2.5275, decay_U mean: 2.5429
# prod_rate_S mean: 2.5429, decay_S mean: 2.5444
#
# Simulating gene 9
# prod_rate_U mean: 2.9522, decay_U mean: 2.9360
# prod_rate_S mean: 2.9360, decay_S mean: 3.0006
# Step 13: Converged = False
#
# --- Iteration step: 14 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6515
# prod_rate_S mean: 0.6515, decay_S mean: 0.6781
#
# Simulating gene 1
# prod_rate_U mean: 0.6921, decay_U mean: 0.6746
# prod_rate_S mean: 0.6746, decay_S mean: 0.7018
#
# Simulating gene 2
# prod_rate_U mean: 0.9578, decay_U mean: 0.9074
# prod_rate_S mean: 0.9074, decay_S mean: 0.9286
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4033
# prod_rate_S mean: 1.4033, decay_S mean: 1.3765
#
# Simulating gene 4
# prod_rate_U mean: 2.3750, decay_U mean: 2.2573
# prod_rate_S mean: 2.2573, decay_S mean: 2.3209
#
# Simulating gene 5
# prod_rate_U mean: 0.9606, decay_U mean: 0.9566
# prod_rate_S mean: 0.9566, decay_S mean: 0.9763
#
# Simulating gene 6
# prod_rate_U mean: 2.5360, decay_U mean: 2.6146
# prod_rate_S mean: 2.6146, decay_S mean: 2.5413
#
# Simulating gene 7
# prod_rate_U mean: 1.0823, decay_U mean: 1.1389
# prod_rate_S mean: 1.1389, decay_S mean: 1.1119
#
# Simulating gene 8
# prod_rate_U mean: 2.5292, decay_U mean: 2.5170
# prod_rate_S mean: 2.5170, decay_S mean: 2.5448
#
# Simulating gene 9
# prod_rate_U mean: 2.9487, decay_U mean: 2.9562
# prod_rate_S mean: 2.9562, decay_S mean: 3.0008
# Step 14: Converged = False
#
# --- Iteration step: 15 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6535
# prod_rate_S mean: 0.6535, decay_S mean: 0.6781
#
# Simulating gene 1
# prod_rate_U mean: 0.6933, decay_U mean: 0.6633
# prod_rate_S mean: 0.6633, decay_S mean: 0.7016
#
# Simulating gene 2
# prod_rate_U mean: 0.9577, decay_U mean: 0.9142
# prod_rate_S mean: 0.9142, decay_S mean: 0.9287
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4050
# prod_rate_S mean: 1.4050, decay_S mean: 1.3760
#
# Simulating gene 4
# prod_rate_U mean: 2.3649, decay_U mean: 2.2514
# prod_rate_S mean: 2.2514, decay_S mean: 2.3190
#
# Simulating gene 5
# prod_rate_U mean: 0.9578, decay_U mean: 0.9515
# prod_rate_S mean: 0.9515, decay_S mean: 0.9765
#
# Simulating gene 6
# prod_rate_U mean: 2.5385, decay_U mean: 2.6192
# prod_rate_S mean: 2.6192, decay_S mean: 2.5415
#
# Simulating gene 7
# prod_rate_U mean: 1.0861, decay_U mean: 1.1353
# prod_rate_S mean: 1.1353, decay_S mean: 1.1125
#
# Simulating gene 8
# prod_rate_U mean: 2.5230, decay_U mean: 2.5145
# prod_rate_S mean: 2.5145, decay_S mean: 2.5426
#
# Simulating gene 9
# prod_rate_U mean: 2.9428, decay_U mean: 2.9704
# prod_rate_S mean: 2.9704, decay_S mean: 2.9998
# Step 15: Converged = False
#
# --- Iteration step: 16 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6519
# prod_rate_S mean: 0.6519, decay_S mean: 0.6772
#
# Simulating gene 1
# prod_rate_U mean: 0.6957, decay_U mean: 0.6635
# prod_rate_S mean: 0.6635, decay_S mean: 0.7019
#
# Simulating gene 2
# prod_rate_U mean: 0.9580, decay_U mean: 0.9230
# prod_rate_S mean: 0.9230, decay_S mean: 0.9288
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4082
# prod_rate_S mean: 1.4082, decay_S mean: 1.3760
#
# Simulating gene 4
# prod_rate_U mean: 2.4046, decay_U mean: 2.2666
# prod_rate_S mean: 2.2666, decay_S mean: 2.3175
#
# Simulating gene 5
# prod_rate_U mean: 0.9550, decay_U mean: 0.9538
# prod_rate_S mean: 0.9538, decay_S mean: 0.9764
#
# Simulating gene 6
# prod_rate_U mean: 2.5463, decay_U mean: 2.6112
# prod_rate_S mean: 2.6112, decay_S mean: 2.5436
#
# Simulating gene 7
# prod_rate_U mean: 1.0986, decay_U mean: 1.1408
# prod_rate_S mean: 1.1408, decay_S mean: 1.1126
#
# Simulating gene 8
# prod_rate_U mean: 2.5116, decay_U mean: 2.5076
# prod_rate_S mean: 2.5076, decay_S mean: 2.5410
#
# Simulating gene 9
# prod_rate_U mean: 2.9425, decay_U mean: 2.9469
# prod_rate_S mean: 2.9469, decay_S mean: 2.9999
# Step 16: Converged = False
#
# --- Iteration step: 17 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6577
# prod_rate_S mean: 0.6577, decay_S mean: 0.6772
#
# Simulating gene 1
# prod_rate_U mean: 0.7089, decay_U mean: 0.6629
# prod_rate_S mean: 0.6629, decay_S mean: 0.7016
#
# Simulating gene 2
# prod_rate_U mean: 0.9551, decay_U mean: 0.9143
# prod_rate_S mean: 0.9143, decay_S mean: 0.9286
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4259
# prod_rate_S mean: 1.4259, decay_S mean: 1.3759
#
# Simulating gene 4
# prod_rate_U mean: 2.4155, decay_U mean: 2.2811
# prod_rate_S mean: 2.2811, decay_S mean: 2.3162
#
# Simulating gene 5
# prod_rate_U mean: 0.9551, decay_U mean: 0.9590
# prod_rate_S mean: 0.9590, decay_S mean: 0.9760
#
# Simulating gene 6
# prod_rate_U mean: 2.5452, decay_U mean: 2.5929
# prod_rate_S mean: 2.5929, decay_S mean: 2.5428
#
# Simulating gene 7
# prod_rate_U mean: 1.0941, decay_U mean: 1.1398
# prod_rate_S mean: 1.1398, decay_S mean: 1.1120
#
# Simulating gene 8
# prod_rate_U mean: 2.5150, decay_U mean: 2.5059
# prod_rate_S mean: 2.5059, decay_S mean: 2.5397
#
# Simulating gene 9
# prod_rate_U mean: 2.9375, decay_U mean: 2.9467
# prod_rate_S mean: 2.9467, decay_S mean: 2.9977
# Step 17: Converged = False
#
# --- Iteration step: 18 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6544
# prod_rate_S mean: 0.6544, decay_S mean: 0.6776
#
# Simulating gene 1
# prod_rate_U mean: 0.7103, decay_U mean: 0.6678
# prod_rate_S mean: 0.6678, decay_S mean: 0.7021
#
# Simulating gene 2
# prod_rate_U mean: 0.9580, decay_U mean: 0.9110
# prod_rate_S mean: 0.9110, decay_S mean: 0.9288
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4279
# prod_rate_S mean: 1.4279, decay_S mean: 1.3767
#
# Simulating gene 4
# prod_rate_U mean: 2.4122, decay_U mean: 2.2810
# prod_rate_S mean: 2.2810, decay_S mean: 2.3167
#
# Simulating gene 5
# prod_rate_U mean: 0.9542, decay_U mean: 0.9591
# prod_rate_S mean: 0.9591, decay_S mean: 0.9756
#
# Simulating gene 6
# prod_rate_U mean: 2.5339, decay_U mean: 2.5993
# prod_rate_S mean: 2.5993, decay_S mean: 2.5418
#
# Simulating gene 7
# prod_rate_U mean: 1.0996, decay_U mean: 1.1321
# prod_rate_S mean: 1.1321, decay_S mean: 1.1116
#
# Simulating gene 8
# prod_rate_U mean: 2.5091, decay_U mean: 2.5007
# prod_rate_S mean: 2.5007, decay_S mean: 2.5386
#
# Simulating gene 9
# prod_rate_U mean: 2.9310, decay_U mean: 2.9547
# prod_rate_S mean: 2.9547, decay_S mean: 2.9981
# Step 18: Converged = False
#
# --- Iteration step: 19 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6559
# prod_rate_S mean: 0.6559, decay_S mean: 0.6770
#
# Simulating gene 1
# prod_rate_U mean: 0.7078, decay_U mean: 0.6628
# prod_rate_S mean: 0.6628, decay_S mean: 0.7028
#
# Simulating gene 2
# prod_rate_U mean: 0.9547, decay_U mean: 0.9116
# prod_rate_S mean: 0.9116, decay_S mean: 0.9290
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4244
# prod_rate_S mean: 1.4244, decay_S mean: 1.3767
#
# Simulating gene 4
# prod_rate_U mean: 2.3845, decay_U mean: 2.2857
# prod_rate_S mean: 2.2857, decay_S mean: 2.3169
#
# Simulating gene 5
# prod_rate_U mean: 0.9529, decay_U mean: 0.9525
# prod_rate_S mean: 0.9525, decay_S mean: 0.9758
#
# Simulating gene 6
# prod_rate_U mean: 2.5285, decay_U mean: 2.5903
# prod_rate_S mean: 2.5903, decay_S mean: 2.5415
#
# Simulating gene 7
# prod_rate_U mean: 1.0962, decay_U mean: 1.1323
# prod_rate_S mean: 1.1323, decay_S mean: 1.1122
#
# Simulating gene 8
# prod_rate_U mean: 2.5106, decay_U mean: 2.4928
# prod_rate_S mean: 2.4928, decay_S mean: 2.5388
#
# Simulating gene 9
# prod_rate_U mean: 2.9327, decay_U mean: 2.9492
# prod_rate_S mean: 2.9492, decay_S mean: 2.9980
# Step 19: Converged = False
#
# --- Iteration step: 20 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6515
# prod_rate_S mean: 0.6515, decay_S mean: 0.6769
#
# Simulating gene 1
# prod_rate_U mean: 0.6994, decay_U mean: 0.6686
# prod_rate_S mean: 0.6686, decay_S mean: 0.7027
#
# Simulating gene 2
# prod_rate_U mean: 0.9546, decay_U mean: 0.9184
# prod_rate_S mean: 0.9184, decay_S mean: 0.9277
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4131
# prod_rate_S mean: 1.4131, decay_S mean: 1.3770
#
# Simulating gene 4
# prod_rate_U mean: 2.3925, decay_U mean: 2.2926
# prod_rate_S mean: 2.2926, decay_S mean: 2.3160
#
# Simulating gene 5
# prod_rate_U mean: 0.9548, decay_U mean: 0.9496
# prod_rate_S mean: 0.9496, decay_S mean: 0.9763
#
# Simulating gene 6
# prod_rate_U mean: 2.5355, decay_U mean: 2.5933
# prod_rate_S mean: 2.5933, decay_S mean: 2.5425
#
# Simulating gene 7
# prod_rate_U mean: 1.0974, decay_U mean: 1.1264
# prod_rate_S mean: 1.1264, decay_S mean: 1.1123
#
# Simulating gene 8
# prod_rate_U mean: 2.5107, decay_U mean: 2.4974
# prod_rate_S mean: 2.4974, decay_S mean: 2.5373
#
# Simulating gene 9
# prod_rate_U mean: 2.9402, decay_U mean: 2.9675
# prod_rate_S mean: 2.9675, decay_S mean: 2.9984
# Step 20: Converged = False
#
# --- Iteration step: 21 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6540
# prod_rate_S mean: 0.6540, decay_S mean: 0.6769
#
# Simulating gene 1
# prod_rate_U mean: 0.6988, decay_U mean: 0.6688
# prod_rate_S mean: 0.6688, decay_S mean: 0.7019
#
# Simulating gene 2
# prod_rate_U mean: 0.9600, decay_U mean: 0.9125
# prod_rate_S mean: 0.9125, decay_S mean: 0.9276
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4124
# prod_rate_S mean: 1.4124, decay_S mean: 1.3765
#
# Simulating gene 4
# prod_rate_U mean: 2.4043, decay_U mean: 2.2823
# prod_rate_S mean: 2.2823, decay_S mean: 2.3155
#
# Simulating gene 5
# prod_rate_U mean: 0.9564, decay_U mean: 0.9538
# prod_rate_S mean: 0.9538, decay_S mean: 0.9767
#
# Simulating gene 6
# prod_rate_U mean: 2.5241, decay_U mean: 2.5932
# prod_rate_S mean: 2.5932, decay_S mean: 2.5435
#
# Simulating gene 7
# prod_rate_U mean: 1.1066, decay_U mean: 1.1305
# prod_rate_S mean: 1.1305, decay_S mean: 1.1125
#
# Simulating gene 8
# prod_rate_U mean: 2.5028, decay_U mean: 2.5071
# prod_rate_S mean: 2.5071, decay_S mean: 2.5390
#
# Simulating gene 9
# prod_rate_U mean: 2.9572, decay_U mean: 2.9745
# prod_rate_S mean: 2.9745, decay_S mean: 2.9986
# Step 21: Converged = False
#
# --- Iteration step: 22 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6600
# prod_rate_S mean: 0.6600, decay_S mean: 0.6765
#
# Simulating gene 1
# prod_rate_U mean: 0.7089, decay_U mean: 0.6591
# prod_rate_S mean: 0.6591, decay_S mean: 0.7020
#
# Simulating gene 2
# prod_rate_U mean: 0.9599, decay_U mean: 0.9169
# prod_rate_S mean: 0.9169, decay_S mean: 0.9279
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4261
# prod_rate_S mean: 1.4261, decay_S mean: 1.3770
#
# Simulating gene 4
# prod_rate_U mean: 2.4189, decay_U mean: 2.2737
# prod_rate_S mean: 2.2737, decay_S mean: 2.3156
#
# Simulating gene 5
# prod_rate_U mean: 0.9552, decay_U mean: 0.9456
# prod_rate_S mean: 0.9456, decay_S mean: 0.9765
#
# Simulating gene 6
# prod_rate_U mean: 2.5362, decay_U mean: 2.5780
# prod_rate_S mean: 2.5780, decay_S mean: 2.5434
#
# Simulating gene 7
# prod_rate_U mean: 1.1196, decay_U mean: 1.1322
# prod_rate_S mean: 1.1322, decay_S mean: 1.1118
#
# Simulating gene 8
# prod_rate_U mean: 2.4949, decay_U mean: 2.5299
# prod_rate_S mean: 2.5299, decay_S mean: 2.5404
#
# Simulating gene 9
# prod_rate_U mean: 2.9701, decay_U mean: 2.9730
# prod_rate_S mean: 2.9730, decay_S mean: 2.9974
# Step 22: Converged = False
#
# --- Iteration step: 23 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6714
# prod_rate_S mean: 0.6714, decay_S mean: 0.6776
#
# Simulating gene 1
# prod_rate_U mean: 0.7048, decay_U mean: 0.6586
# prod_rate_S mean: 0.6586, decay_S mean: 0.7018
#
# Simulating gene 2
# prod_rate_U mean: 0.9540, decay_U mean: 0.9054
# prod_rate_S mean: 0.9054, decay_S mean: 0.9275
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4205
# prod_rate_S mean: 1.4205, decay_S mean: 1.3774
#
# Simulating gene 4
# prod_rate_U mean: 2.4085, decay_U mean: 2.2796
# prod_rate_S mean: 2.2796, decay_S mean: 2.3157
#
# Simulating gene 5
# prod_rate_U mean: 0.9553, decay_U mean: 0.9516
# prod_rate_S mean: 0.9516, decay_S mean: 0.9760
#
# Simulating gene 6
# prod_rate_U mean: 2.5204, decay_U mean: 2.5652
# prod_rate_S mean: 2.5652, decay_S mean: 2.5444
#
# Simulating gene 7
# prod_rate_U mean: 1.1326, decay_U mean: 1.1368
# prod_rate_S mean: 1.1368, decay_S mean: 1.1110
#
# Simulating gene 8
# prod_rate_U mean: 2.4818, decay_U mean: 2.5466
# prod_rate_S mean: 2.5466, decay_S mean: 2.5417
#
# Simulating gene 9
# prod_rate_U mean: 2.9717, decay_U mean: 2.9570
# prod_rate_S mean: 2.9570, decay_S mean: 2.9987
# Step 23: Converged = False
#
# --- Iteration step: 24 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6762
# prod_rate_S mean: 0.6762, decay_S mean: 0.6779
#
# Simulating gene 1
# prod_rate_U mean: 0.7085, decay_U mean: 0.6690
# prod_rate_S mean: 0.6690, decay_S mean: 0.7014
#
# Simulating gene 2
# prod_rate_U mean: 0.9553, decay_U mean: 0.9147
# prod_rate_S mean: 0.9147, decay_S mean: 0.9273
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4254
# prod_rate_S mean: 1.4254, decay_S mean: 1.3770
#
# Simulating gene 4
# prod_rate_U mean: 2.4076, decay_U mean: 2.2795
# prod_rate_S mean: 2.2795, decay_S mean: 2.3157
#
# Simulating gene 5
# prod_rate_U mean: 0.9572, decay_U mean: 0.9437
# prod_rate_S mean: 0.9437, decay_S mean: 0.9750
#
# Simulating gene 6
# prod_rate_U mean: 2.5249, decay_U mean: 2.5454
# prod_rate_S mean: 2.5454, decay_S mean: 2.5453
#
# Simulating gene 7
# prod_rate_U mean: 1.1320, decay_U mean: 1.1384
# prod_rate_S mean: 1.1384, decay_S mean: 1.1115
#
# Simulating gene 8
# prod_rate_U mean: 2.4881, decay_U mean: 2.5488
# prod_rate_S mean: 2.5488, decay_S mean: 2.5419
#
# Simulating gene 9
# prod_rate_U mean: 2.9785, decay_U mean: 2.9642
# prod_rate_S mean: 2.9642, decay_S mean: 3.0005
# Step 24: Converged = False
#
# --- Iteration step: 25 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6826
# prod_rate_S mean: 0.6826, decay_S mean: 0.6778
#
# Simulating gene 1
# prod_rate_U mean: 0.7123, decay_U mean: 0.6671
# prod_rate_S mean: 0.6671, decay_S mean: 0.7010
#
# Simulating gene 2
# prod_rate_U mean: 0.9579, decay_U mean: 0.9179
# prod_rate_S mean: 0.9179, decay_S mean: 0.9276
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4306
# prod_rate_S mean: 1.4306, decay_S mean: 1.3774
#
# Simulating gene 4
# prod_rate_U mean: 2.3957, decay_U mean: 2.2693
# prod_rate_S mean: 2.2693, decay_S mean: 2.3168
#
# Simulating gene 5
# prod_rate_U mean: 0.9529, decay_U mean: 0.9476
# prod_rate_S mean: 0.9476, decay_S mean: 0.9742
#
# Simulating gene 6
# prod_rate_U mean: 2.5228, decay_U mean: 2.5545
# prod_rate_S mean: 2.5545, decay_S mean: 2.5448
#
# Simulating gene 7
# prod_rate_U mean: 1.1325, decay_U mean: 1.1384
# prod_rate_S mean: 1.1384, decay_S mean: 1.1110
#
# Simulating gene 8
# prod_rate_U mean: 2.4906, decay_U mean: 2.5584
# prod_rate_S mean: 2.5584, decay_S mean: 2.5428
#
# Simulating gene 9
# prod_rate_U mean: 2.9694, decay_U mean: 2.9608
# prod_rate_S mean: 2.9608, decay_S mean: 2.9992
# Step 25: Converged = False
#
# --- Iteration step: 26 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6861
# prod_rate_S mean: 0.6861, decay_S mean: 0.6772
#
# Simulating gene 1
# prod_rate_U mean: 0.7096, decay_U mean: 0.6625
# prod_rate_S mean: 0.6625, decay_S mean: 0.7010
#
# Simulating gene 2
# prod_rate_U mean: 0.9586, decay_U mean: 0.9216
# prod_rate_S mean: 0.9216, decay_S mean: 0.9283
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4269
# prod_rate_S mean: 1.4269, decay_S mean: 1.3778
#
# Simulating gene 4
# prod_rate_U mean: 2.3905, decay_U mean: 2.2917
# prod_rate_S mean: 2.2917, decay_S mean: 2.3161
#
# Simulating gene 5
# prod_rate_U mean: 0.9530, decay_U mean: 0.9466
# prod_rate_S mean: 0.9466, decay_S mean: 0.9740
#
# Simulating gene 6
# prod_rate_U mean: 2.5120, decay_U mean: 2.5591
# prod_rate_S mean: 2.5591, decay_S mean: 2.5450
#
# Simulating gene 7
# prod_rate_U mean: 1.1281, decay_U mean: 1.1468
# prod_rate_S mean: 1.1468, decay_S mean: 1.1105
#
# Simulating gene 8
# prod_rate_U mean: 2.4910, decay_U mean: 2.5447
# prod_rate_S mean: 2.5447, decay_S mean: 2.5425
#
# Simulating gene 9
# prod_rate_U mean: 2.9743, decay_U mean: 2.9603
# prod_rate_S mean: 2.9603, decay_S mean: 2.9996
# Step 26: Converged = False
#
# --- Iteration step: 27 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6804
# prod_rate_S mean: 0.6804, decay_S mean: 0.6771
#
# Simulating gene 1
# prod_rate_U mean: 0.7044, decay_U mean: 0.6613
# prod_rate_S mean: 0.6613, decay_S mean: 0.7008
#
# Simulating gene 2
# prod_rate_U mean: 0.9585, decay_U mean: 0.9202
# prod_rate_S mean: 0.9202, decay_S mean: 0.9287
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4199
# prod_rate_S mean: 1.4199, decay_S mean: 1.3785
#
# Simulating gene 4
# prod_rate_U mean: 2.4120, decay_U mean: 2.2911
# prod_rate_S mean: 2.2911, decay_S mean: 2.3164
#
# Simulating gene 5
# prod_rate_U mean: 0.9516, decay_U mean: 0.9404
# prod_rate_S mean: 0.9404, decay_S mean: 0.9737
#
# Simulating gene 6
# prod_rate_U mean: 2.5111, decay_U mean: 2.5590
# prod_rate_S mean: 2.5590, decay_S mean: 2.5461
#
# Simulating gene 7
# prod_rate_U mean: 1.1263, decay_U mean: 1.1600
# prod_rate_S mean: 1.1600, decay_S mean: 1.1105
#
# Simulating gene 8
# prod_rate_U mean: 2.4948, decay_U mean: 2.5504
# prod_rate_S mean: 2.5504, decay_S mean: 2.5430
#
# Simulating gene 9
# prod_rate_U mean: 2.9741, decay_U mean: 2.9614
# prod_rate_S mean: 2.9614, decay_S mean: 2.9992
# Step 27: Converged = False
#
# --- Iteration step: 28 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6819
# prod_rate_S mean: 0.6819, decay_S mean: 0.6775
#
# Simulating gene 1
# prod_rate_U mean: 0.7128, decay_U mean: 0.6611
# prod_rate_S mean: 0.6611, decay_S mean: 0.7007
#
# Simulating gene 2
# prod_rate_U mean: 0.9596, decay_U mean: 0.9164
# prod_rate_S mean: 0.9164, decay_S mean: 0.9284
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4312
# prod_rate_S mean: 1.4312, decay_S mean: 1.3784
#
# Simulating gene 4
# prod_rate_U mean: 2.4076, decay_U mean: 2.2991
# prod_rate_S mean: 2.2991, decay_S mean: 2.3156
#
# Simulating gene 5
# prod_rate_U mean: 0.9509, decay_U mean: 0.9402
# prod_rate_S mean: 0.9402, decay_S mean: 0.9741
#
# Simulating gene 6
# prod_rate_U mean: 2.5287, decay_U mean: 2.5661
# prod_rate_S mean: 2.5661, decay_S mean: 2.5460
#
# Simulating gene 7
# prod_rate_U mean: 1.1228, decay_U mean: 1.1640
# prod_rate_S mean: 1.1640, decay_S mean: 1.1093
#
# Simulating gene 8
# prod_rate_U mean: 2.4956, decay_U mean: 2.5509
# prod_rate_S mean: 2.5509, decay_S mean: 2.5428
#
# Simulating gene 9
# prod_rate_U mean: 2.9786, decay_U mean: 2.9483
# prod_rate_S mean: 2.9483, decay_S mean: 2.9980
# Step 28: Converged = False
#
# --- Iteration step: 29 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6774
# prod_rate_S mean: 0.6774, decay_S mean: 0.6781
#
# Simulating gene 1
# prod_rate_U mean: 0.7057, decay_U mean: 0.6591
# prod_rate_S mean: 0.6591, decay_S mean: 0.7003
#
# Simulating gene 2
# prod_rate_U mean: 0.9599, decay_U mean: 0.9112
# prod_rate_S mean: 0.9112, decay_S mean: 0.9283
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4216
# prod_rate_S mean: 1.4216, decay_S mean: 1.3779
#
# Simulating gene 4
# prod_rate_U mean: 2.4090, decay_U mean: 2.3031
# prod_rate_S mean: 2.3031, decay_S mean: 2.3141
#
# Simulating gene 5
# prod_rate_U mean: 0.9509, decay_U mean: 0.9486
# prod_rate_S mean: 0.9486, decay_S mean: 0.9739
#
# Simulating gene 6
# prod_rate_U mean: 2.5184, decay_U mean: 2.5680
# prod_rate_S mean: 2.5680, decay_S mean: 2.5463
#
# Simulating gene 7
# prod_rate_U mean: 1.1338, decay_U mean: 1.1622
# prod_rate_S mean: 1.1622, decay_S mean: 1.1092
#
# Simulating gene 8
# prod_rate_U mean: 2.4808, decay_U mean: 2.5557
# prod_rate_S mean: 2.5557, decay_S mean: 2.5436
#
# Simulating gene 9
# prod_rate_U mean: 2.9791, decay_U mean: 2.9610
# prod_rate_S mean: 2.9610, decay_S mean: 2.9972
# Step 29: Converged = False
#
# --- Iteration step: 30 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6763
# prod_rate_S mean: 0.6763, decay_S mean: 0.6786
#
# Simulating gene 1
# prod_rate_U mean: 0.6989, decay_U mean: 0.6584
# prod_rate_S mean: 0.6584, decay_S mean: 0.7000
#
# Simulating gene 2
# prod_rate_U mean: 0.9651, decay_U mean: 0.9054
# prod_rate_S mean: 0.9054, decay_S mean: 0.9270
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4124
# prod_rate_S mean: 1.4124, decay_S mean: 1.3794
#
# Simulating gene 4
# prod_rate_U mean: 2.4074, decay_U mean: 2.3027
# prod_rate_S mean: 2.3027, decay_S mean: 2.3157
#
# Simulating gene 5
# prod_rate_U mean: 0.9487, decay_U mean: 0.9443
# prod_rate_S mean: 0.9443, decay_S mean: 0.9737
#
# Simulating gene 6
# prod_rate_U mean: 2.5170, decay_U mean: 2.5474
# prod_rate_S mean: 2.5474, decay_S mean: 2.5475
#
# Simulating gene 7
# prod_rate_U mean: 1.1276, decay_U mean: 1.1650
# prod_rate_S mean: 1.1650, decay_S mean: 1.1096
#
# Simulating gene 8
# prod_rate_U mean: 2.4862, decay_U mean: 2.5575
# prod_rate_S mean: 2.5575, decay_S mean: 2.5422
#
# Simulating gene 9
# prod_rate_U mean: 2.9820, decay_U mean: 2.9719
# prod_rate_S mean: 2.9719, decay_S mean: 2.9977
# Step 30: Converged = False
#
# --- Iteration step: 31 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6727
# prod_rate_S mean: 0.6727, decay_S mean: 0.6787
#
# Simulating gene 1
# prod_rate_U mean: 0.7006, decay_U mean: 0.6490
# prod_rate_S mean: 0.6490, decay_S mean: 0.7000
#
# Simulating gene 2
# prod_rate_U mean: 0.9616, decay_U mean: 0.9081
# prod_rate_S mean: 0.9081, decay_S mean: 0.9270
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4147
# prod_rate_S mean: 1.4147, decay_S mean: 1.3794
#
# Simulating gene 4
# prod_rate_U mean: 2.4091, decay_U mean: 2.3146
# prod_rate_S mean: 2.3146, decay_S mean: 2.3160
#
# Simulating gene 5
# prod_rate_U mean: 0.9501, decay_U mean: 0.9435
# prod_rate_S mean: 0.9435, decay_S mean: 0.9731
#
# Simulating gene 6
# prod_rate_U mean: 2.5075, decay_U mean: 2.5533
# prod_rate_S mean: 2.5533, decay_S mean: 2.5481
#
# Simulating gene 7
# prod_rate_U mean: 1.1199, decay_U mean: 1.1655
# prod_rate_S mean: 1.1655, decay_S mean: 1.1094
#
# Simulating gene 8
# prod_rate_U mean: 2.4991, decay_U mean: 2.5605
# prod_rate_S mean: 2.5605, decay_S mean: 2.5434
#
# Simulating gene 9
# prod_rate_U mean: 2.9859, decay_U mean: 2.9654
# prod_rate_S mean: 2.9654, decay_S mean: 2.9975
# Step 31: Converged = False
#
# --- Iteration step: 32 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6756
# prod_rate_S mean: 0.6756, decay_S mean: 0.6788
#
# Simulating gene 1
# prod_rate_U mean: 0.6985, decay_U mean: 0.6555
# prod_rate_S mean: 0.6555, decay_S mean: 0.7000
#
# Simulating gene 2
# prod_rate_U mean: 0.9656, decay_U mean: 0.9067
# prod_rate_S mean: 0.9067, decay_S mean: 0.9275
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4119
# prod_rate_S mean: 1.4119, decay_S mean: 1.3798
#
# Simulating gene 4
# prod_rate_U mean: 2.3948, decay_U mean: 2.3073
# prod_rate_S mean: 2.3073, decay_S mean: 2.3150
#
# Simulating gene 5
# prod_rate_U mean: 0.9502, decay_U mean: 0.9372
# prod_rate_S mean: 0.9372, decay_S mean: 0.9728
#
# Simulating gene 6
# prod_rate_U mean: 2.5208, decay_U mean: 2.5698
# prod_rate_S mean: 2.5698, decay_S mean: 2.5482
#
# Simulating gene 7
# prod_rate_U mean: 1.1238, decay_U mean: 1.1683
# prod_rate_S mean: 1.1683, decay_S mean: 1.1085
#
# Simulating gene 8
# prod_rate_U mean: 2.4933, decay_U mean: 2.5652
# prod_rate_S mean: 2.5652, decay_S mean: 2.5458
#
# Simulating gene 9
# prod_rate_U mean: 2.9827, decay_U mean: 2.9886
# prod_rate_S mean: 2.9886, decay_S mean: 2.9976
# Step 32: Converged = False
#
# --- Iteration step: 33 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6757
# prod_rate_S mean: 0.6757, decay_S mean: 0.6789
#
# Simulating gene 1
# prod_rate_U mean: 0.7004, decay_U mean: 0.6478
# prod_rate_S mean: 0.6478, decay_S mean: 0.7000
#
# Simulating gene 2
# prod_rate_U mean: 0.9638, decay_U mean: 0.9177
# prod_rate_S mean: 0.9177, decay_S mean: 0.9277
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4144
# prod_rate_S mean: 1.4144, decay_S mean: 1.3800
#
# Simulating gene 4
# prod_rate_U mean: 2.4084, decay_U mean: 2.3065
# prod_rate_S mean: 2.3065, decay_S mean: 2.3144
#
# Simulating gene 5
# prod_rate_U mean: 0.9473, decay_U mean: 0.9434
# prod_rate_S mean: 0.9434, decay_S mean: 0.9727
#
# Simulating gene 6
# prod_rate_U mean: 2.5224, decay_U mean: 2.5610
# prod_rate_S mean: 2.5610, decay_S mean: 2.5485
#
# Simulating gene 7
# prod_rate_U mean: 1.1388, decay_U mean: 1.1689
# prod_rate_S mean: 1.1689, decay_S mean: 1.1088
#
# Simulating gene 8
# prod_rate_U mean: 2.4780, decay_U mean: 2.5586
# prod_rate_S mean: 2.5586, decay_S mean: 2.5462
#
# Simulating gene 9
# prod_rate_U mean: 2.9947, decay_U mean: 2.9998
# prod_rate_S mean: 2.9998, decay_S mean: 2.9969
# Step 33: Converged = False
#
# --- Iteration step: 34 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6817
# prod_rate_S mean: 0.6817, decay_S mean: 0.6788
#
# Simulating gene 1
# prod_rate_U mean: 0.7073, decay_U mean: 0.6512
# prod_rate_S mean: 0.6512, decay_S mean: 0.7002
#
# Simulating gene 2
# prod_rate_U mean: 0.9639, decay_U mean: 0.9181
# prod_rate_S mean: 0.9181, decay_S mean: 0.9283
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4237
# prod_rate_S mean: 1.4237, decay_S mean: 1.3788
#
# Simulating gene 4
# prod_rate_U mean: 2.3973, decay_U mean: 2.3223
# prod_rate_S mean: 2.3223, decay_S mean: 2.3146
#
# Simulating gene 5
# prod_rate_U mean: 0.9472, decay_U mean: 0.9456
# prod_rate_S mean: 0.9456, decay_S mean: 0.9730
#
# Simulating gene 6
# prod_rate_U mean: 2.5192, decay_U mean: 2.5370
# prod_rate_S mean: 2.5370, decay_S mean: 2.5482
#
# Simulating gene 7
# prod_rate_U mean: 1.1379, decay_U mean: 1.1675
# prod_rate_S mean: 1.1675, decay_S mean: 1.1093
#
# Simulating gene 8
# prod_rate_U mean: 2.4736, decay_U mean: 2.5750
# prod_rate_S mean: 2.5750, decay_S mean: 2.5471
#
# Simulating gene 9
# prod_rate_U mean: 2.9812, decay_U mean: 3.0133
# prod_rate_S mean: 3.0133, decay_S mean: 2.9968
# Step 34: Converged = False
#
# --- Iteration step: 35 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6753
# prod_rate_S mean: 0.6753, decay_S mean: 0.6788
#
# Simulating gene 1
# prod_rate_U mean: 0.6995, decay_U mean: 0.6509
# prod_rate_S mean: 0.6509, decay_S mean: 0.7004
#
# Simulating gene 2
# prod_rate_U mean: 0.9665, decay_U mean: 0.9153
# prod_rate_S mean: 0.9153, decay_S mean: 0.9285
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4133
# prod_rate_S mean: 1.4133, decay_S mean: 1.3789
#
# Simulating gene 4
# prod_rate_U mean: 2.3989, decay_U mean: 2.3230
# prod_rate_S mean: 2.3230, decay_S mean: 2.3141
#
# Simulating gene 5
# prod_rate_U mean: 0.9480, decay_U mean: 0.9435
# prod_rate_S mean: 0.9435, decay_S mean: 0.9734
#
# Simulating gene 6
# prod_rate_U mean: 2.5410, decay_U mean: 2.5309
# prod_rate_S mean: 2.5309, decay_S mean: 2.5485
#
# Simulating gene 7
# prod_rate_U mean: 1.1362, decay_U mean: 1.1702
# prod_rate_S mean: 1.1702, decay_S mean: 1.1093
#
# Simulating gene 8
# prod_rate_U mean: 2.4805, decay_U mean: 2.5584
# prod_rate_S mean: 2.5584, decay_S mean: 2.5460
#
# Simulating gene 9
# prod_rate_U mean: 2.9826, decay_U mean: 3.0246
# prod_rate_S mean: 3.0246, decay_S mean: 2.9974
# Step 35: Converged = False
#
# --- Iteration step: 36 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6802
# prod_rate_S mean: 0.6802, decay_S mean: 0.6784
#
# Simulating gene 1
# prod_rate_U mean: 0.6997, decay_U mean: 0.6462
# prod_rate_S mean: 0.6462, decay_S mean: 0.7005
#
# Simulating gene 2
# prod_rate_U mean: 0.9665, decay_U mean: 0.9145
# prod_rate_S mean: 0.9145, decay_S mean: 0.9284
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4135
# prod_rate_S mean: 1.4135, decay_S mean: 1.3785
#
# Simulating gene 4
# prod_rate_U mean: 2.3933, decay_U mean: 2.3182
# prod_rate_S mean: 2.3182, decay_S mean: 2.3139
#
# Simulating gene 5
# prod_rate_U mean: 0.9466, decay_U mean: 0.9563
# prod_rate_S mean: 0.9563, decay_S mean: 0.9731
#
# Simulating gene 6
# prod_rate_U mean: 2.5475, decay_U mean: 2.5419
# prod_rate_S mean: 2.5419, decay_S mean: 2.5481
#
# Simulating gene 7
# prod_rate_U mean: 1.1338, decay_U mean: 1.1745
# prod_rate_S mean: 1.1745, decay_S mean: 1.1091
#
# Simulating gene 8
# prod_rate_U mean: 2.4851, decay_U mean: 2.5599
# prod_rate_S mean: 2.5599, decay_S mean: 2.5445
#
# Simulating gene 9
# prod_rate_U mean: 2.9730, decay_U mean: 3.0144
# prod_rate_S mean: 3.0144, decay_S mean: 2.9990
# Step 36: Converged = False
#
# --- Iteration step: 37 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6805
# prod_rate_S mean: 0.6805, decay_S mean: 0.6789
#
# Simulating gene 1
# prod_rate_U mean: 0.6978, decay_U mean: 0.6455
# prod_rate_S mean: 0.6455, decay_S mean: 0.7014
#
# Simulating gene 2
# prod_rate_U mean: 0.9649, decay_U mean: 0.9145
# prod_rate_S mean: 0.9145, decay_S mean: 0.9280
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4110
# prod_rate_S mean: 1.4110, decay_S mean: 1.3786
#
# Simulating gene 4
# prod_rate_U mean: 2.3877, decay_U mean: 2.3260
# prod_rate_S mean: 2.3260, decay_S mean: 2.3147
#
# Simulating gene 5
# prod_rate_U mean: 0.9467, decay_U mean: 0.9601
# prod_rate_S mean: 0.9601, decay_S mean: 0.9733
#
# Simulating gene 6
# prod_rate_U mean: 2.5439, decay_U mean: 2.5463
# prod_rate_S mean: 2.5463, decay_S mean: 2.5469
#
# Simulating gene 7
# prod_rate_U mean: 1.1383, decay_U mean: 1.1775
# prod_rate_S mean: 1.1775, decay_S mean: 1.1085
#
# Simulating gene 8
# prod_rate_U mean: 2.4845, decay_U mean: 2.5493
# prod_rate_S mean: 2.5493, decay_S mean: 2.5431
#
# Simulating gene 9
# prod_rate_U mean: 2.9751, decay_U mean: 3.0170
# prod_rate_S mean: 3.0170, decay_S mean: 2.9992
# Step 37: Converged = False
#
# --- Iteration step: 38 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6865
# prod_rate_S mean: 0.6865, decay_S mean: 0.6791
#
# Simulating gene 1
# prod_rate_U mean: 0.6994, decay_U mean: 0.6491
# prod_rate_S mean: 0.6491, decay_S mean: 0.7016
#
# Simulating gene 2
# prod_rate_U mean: 0.9629, decay_U mean: 0.9173
# prod_rate_S mean: 0.9173, decay_S mean: 0.9278
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4131
# prod_rate_S mean: 1.4131, decay_S mean: 1.3785
#
# Simulating gene 4
# prod_rate_U mean: 2.3929, decay_U mean: 2.3253
# prod_rate_S mean: 2.3253, decay_S mean: 2.3147
#
# Simulating gene 5
# prod_rate_U mean: 0.9466, decay_U mean: 0.9590
# prod_rate_S mean: 0.9590, decay_S mean: 0.9733
#
# Simulating gene 6
# prod_rate_U mean: 2.5537, decay_U mean: 2.5467
# prod_rate_S mean: 2.5467, decay_S mean: 2.5452
#
# Simulating gene 7
# prod_rate_U mean: 1.1328, decay_U mean: 1.1787
# prod_rate_S mean: 1.1787, decay_S mean: 1.1087
#
# Simulating gene 8
# prod_rate_U mean: 2.4921, decay_U mean: 2.5508
# prod_rate_S mean: 2.5508, decay_S mean: 2.5425
#
# Simulating gene 9
# prod_rate_U mean: 2.9752, decay_U mean: 3.0198
# prod_rate_S mean: 3.0198, decay_S mean: 2.9977
# Step 38: Converged = False
#
# --- Iteration step: 39 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6865
# prod_rate_S mean: 0.6865, decay_S mean: 0.6792
#
# Simulating gene 1
# prod_rate_U mean: 0.7004, decay_U mean: 0.6528
# prod_rate_S mean: 0.6528, decay_S mean: 0.7019
#
# Simulating gene 2
# prod_rate_U mean: 0.9641, decay_U mean: 0.9175
# prod_rate_S mean: 0.9175, decay_S mean: 0.9278
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4144
# prod_rate_S mean: 1.4144, decay_S mean: 1.3780
#
# Simulating gene 4
# prod_rate_U mean: 2.4061, decay_U mean: 2.3258
# prod_rate_S mean: 2.3258, decay_S mean: 2.3149
#
# Simulating gene 5
# prod_rate_U mean: 0.9476, decay_U mean: 0.9647
# prod_rate_S mean: 0.9647, decay_S mean: 0.9734
#
# Simulating gene 6
# prod_rate_U mean: 2.5583, decay_U mean: 2.5593
# prod_rate_S mean: 2.5593, decay_S mean: 2.5444
#
# Simulating gene 7
# prod_rate_U mean: 1.1335, decay_U mean: 1.1730
# prod_rate_S mean: 1.1730, decay_S mean: 1.1082
#
# Simulating gene 8
# prod_rate_U mean: 2.4908, decay_U mean: 2.5523
# prod_rate_S mean: 2.5523, decay_S mean: 2.5430
#
# Simulating gene 9
# prod_rate_U mean: 2.9705, decay_U mean: 3.0206
# prod_rate_S mean: 3.0206, decay_S mean: 2.9975
# Step 39: Converged = False
#
# --- Iteration step: 40 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.6739, decay_U mean: 0.6857
# prod_rate_S mean: 0.6857, decay_S mean: 0.6790
#
# Simulating gene 1
# prod_rate_U mean: 0.7111, decay_U mean: 0.6509
# prod_rate_S mean: 0.6509, decay_S mean: 0.7023
#
# Simulating gene 2
# prod_rate_U mean: 0.9619, decay_U mean: 0.9203
# prod_rate_S mean: 0.9203, decay_S mean: 0.9275
#
# Simulating gene 3
# prod_rate_U mean: 1.3876, decay_U mean: 1.4288
# prod_rate_S mean: 1.4288, decay_S mean: 1.3780
#
# Simulating gene 4
# ...
#
# Simulating gene 9
# prod_rate_U mean: 2.4703, decay_U mean: 2.4234
# prod_rate_S mean: 2.4234, decay_S mean: 2.1185
# Step 1442: Converged = False
#
# --- Iteration step: 1443 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5105
# prod_rate_S mean: 0.5105, decay_S mean: 0.7218
#
# Simulating gene 1
# prod_rate_U mean: 1.0824, decay_U mean: 1.0862
# prod_rate_S mean: 1.0862, decay_S mean: 1.1632
#
# Simulating gene 2
# prod_rate_U mean: 0.7284, decay_U mean: 0.7194
# prod_rate_S mean: 0.7194, decay_S mean: 0.6746
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9498
# prod_rate_S mean: 1.9498, decay_S mean: 2.0585
#
# Simulating gene 4
# prod_rate_U mean: 3.5153, decay_U mean: 3.5547
# prod_rate_S mean: 3.5547, decay_S mean: 3.8050
#
# Simulating gene 5
# prod_rate_U mean: 0.7284, decay_U mean: 0.7318
# prod_rate_S mean: 0.7318, decay_S mean: 0.6843
#
# Simulating gene 6
# prod_rate_U mean: 2.0360, decay_U mean: 2.0170
# prod_rate_S mean: 2.0170, decay_S mean: 1.8461
#
# Simulating gene 7
# prod_rate_U mean: 1.3684, decay_U mean: 1.3776
# prod_rate_S mean: 1.3776, decay_S mean: 1.7039
#
# Simulating gene 8
# prod_rate_U mean: 2.0422, decay_U mean: 2.0347
# prod_rate_S mean: 2.0347, decay_S mean: 1.8198
#
# Simulating gene 9
# prod_rate_U mean: 2.4688, decay_U mean: 2.4254
# prod_rate_S mean: 2.4254, decay_S mean: 2.1188
# Step 1443: Converged = False
#
# --- Iteration step: 1444 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5113
# prod_rate_S mean: 0.5113, decay_S mean: 0.7213
#
# Simulating gene 1
# prod_rate_U mean: 1.0821, decay_U mean: 1.0845
# prod_rate_S mean: 1.0845, decay_S mean: 1.1632
#
# Simulating gene 2
# prod_rate_U mean: 0.7285, decay_U mean: 0.7212
# prod_rate_S mean: 0.7212, decay_S mean: 0.6747
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9495
# prod_rate_S mean: 1.9495, decay_S mean: 2.0583
#
# Simulating gene 4
# prod_rate_U mean: 3.5239, decay_U mean: 3.5579
# prod_rate_S mean: 3.5579, decay_S mean: 3.8044
#
# Simulating gene 5
# prod_rate_U mean: 0.7279, decay_U mean: 0.7326
# prod_rate_S mean: 0.7326, decay_S mean: 0.6844
#
# Simulating gene 6
# prod_rate_U mean: 2.0395, decay_U mean: 2.0146
# prod_rate_S mean: 2.0146, decay_S mean: 1.8468
#
# Simulating gene 7
# prod_rate_U mean: 1.3695, decay_U mean: 1.3795
# prod_rate_S mean: 1.3795, decay_S mean: 1.7035
#
# Simulating gene 8
# prod_rate_U mean: 2.0400, decay_U mean: 2.0329
# prod_rate_S mean: 2.0329, decay_S mean: 1.8204
#
# Simulating gene 9
# prod_rate_U mean: 2.4689, decay_U mean: 2.4299
# prod_rate_S mean: 2.4299, decay_S mean: 2.1196
# Step 1444: Converged = False
#
# --- Iteration step: 1445 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5105
# prod_rate_S mean: 0.5105, decay_S mean: 0.7210
#
# Simulating gene 1
# prod_rate_U mean: 1.0835, decay_U mean: 1.0844
# prod_rate_S mean: 1.0844, decay_S mean: 1.1630
#
# Simulating gene 2
# prod_rate_U mean: 0.7274, decay_U mean: 0.7193
# prod_rate_S mean: 0.7193, decay_S mean: 0.6747
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9518
# prod_rate_S mean: 1.9518, decay_S mean: 2.0580
#
# Simulating gene 4
# prod_rate_U mean: 3.5257, decay_U mean: 3.5615
# prod_rate_S mean: 3.5615, decay_S mean: 3.8038
#
# Simulating gene 5
# prod_rate_U mean: 0.7279, decay_U mean: 0.7344
# prod_rate_S mean: 0.7344, decay_S mean: 0.6846
#
# Simulating gene 6
# prod_rate_U mean: 2.0413, decay_U mean: 2.0126
# prod_rate_S mean: 2.0126, decay_S mean: 1.8471
#
# Simulating gene 7
# prod_rate_U mean: 1.3704, decay_U mean: 1.3798
# prod_rate_S mean: 1.3798, decay_S mean: 1.7029
#
# Simulating gene 8
# prod_rate_U mean: 2.0386, decay_U mean: 2.0329
# prod_rate_S mean: 2.0329, decay_S mean: 1.8211
#
# Simulating gene 9
# prod_rate_U mean: 2.4697, decay_U mean: 2.4282
# prod_rate_S mean: 2.4282, decay_S mean: 2.1203
# Step 1445: Converged = False
#
# --- Iteration step: 1446 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5104
# prod_rate_S mean: 0.5104, decay_S mean: 0.7206
#
# Simulating gene 1
# prod_rate_U mean: 1.0856, decay_U mean: 1.0868
# prod_rate_S mean: 1.0868, decay_S mean: 1.1629
#
# Simulating gene 2
# prod_rate_U mean: 0.7298, decay_U mean: 0.7198
# prod_rate_S mean: 0.7198, decay_S mean: 0.6749
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9548
# prod_rate_S mean: 1.9548, decay_S mean: 2.0576
#
# Simulating gene 4
# prod_rate_U mean: 3.5241, decay_U mean: 3.5611
# prod_rate_S mean: 3.5611, decay_S mean: 3.8036
#
# Simulating gene 5
# prod_rate_U mean: 0.7278, decay_U mean: 0.7348
# prod_rate_S mean: 0.7348, decay_S mean: 0.6848
#
# Simulating gene 6
# prod_rate_U mean: 2.0430, decay_U mean: 2.0115
# prod_rate_S mean: 2.0115, decay_S mean: 1.8475
#
# Simulating gene 7
# prod_rate_U mean: 1.3687, decay_U mean: 1.3792
# prod_rate_S mean: 1.3792, decay_S mean: 1.7021
#
# Simulating gene 8
# prod_rate_U mean: 2.0397, decay_U mean: 2.0331
# prod_rate_S mean: 2.0331, decay_S mean: 1.8217
#
# Simulating gene 9
# prod_rate_U mean: 2.4710, decay_U mean: 2.4262
# prod_rate_S mean: 2.4262, decay_S mean: 2.1210
# Step 1446: Converged = False
#
# --- Iteration step: 1447 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5088
# prod_rate_S mean: 0.5088, decay_S mean: 0.7202
#
# Simulating gene 1
# prod_rate_U mean: 1.0860, decay_U mean: 1.0822
# prod_rate_S mean: 1.0822, decay_S mean: 1.1628
#
# Simulating gene 2
# prod_rate_U mean: 0.7300, decay_U mean: 0.7206
# prod_rate_S mean: 0.7206, decay_S mean: 0.6750
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9553
# prod_rate_S mean: 1.9553, decay_S mean: 2.0576
#
# Simulating gene 4
# prod_rate_U mean: 3.5265, decay_U mean: 3.5621
# prod_rate_S mean: 3.5621, decay_S mean: 3.8033
#
# Simulating gene 5
# prod_rate_U mean: 0.7281, decay_U mean: 0.7350
# prod_rate_S mean: 0.7350, decay_S mean: 0.6849
#
# Simulating gene 6
# prod_rate_U mean: 2.0449, decay_U mean: 2.0128
# prod_rate_S mean: 2.0128, decay_S mean: 1.8482
#
# Simulating gene 7
# prod_rate_U mean: 1.3691, decay_U mean: 1.3756
# prod_rate_S mean: 1.3756, decay_S mean: 1.7015
#
# Simulating gene 8
# prod_rate_U mean: 2.0392, decay_U mean: 2.0347
# prod_rate_S mean: 2.0347, decay_S mean: 1.8225
#
# Simulating gene 9
# prod_rate_U mean: 2.4721, decay_U mean: 2.4287
# prod_rate_S mean: 2.4287, decay_S mean: 2.1216
# Step 1447: Converged = False
#
# --- Iteration step: 1448 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5090
# prod_rate_S mean: 0.5090, decay_S mean: 0.7199
#
# Simulating gene 1
# prod_rate_U mean: 1.0861, decay_U mean: 1.0821
# prod_rate_S mean: 1.0821, decay_S mean: 1.1624
#
# Simulating gene 2
# prod_rate_U mean: 0.7303, decay_U mean: 0.7193
# prod_rate_S mean: 0.7193, decay_S mean: 0.6750
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9555
# prod_rate_S mean: 1.9555, decay_S mean: 2.0574
#
# Simulating gene 4
# prod_rate_U mean: 3.5382, decay_U mean: 3.5602
# prod_rate_S mean: 3.5602, decay_S mean: 3.8034
#
# Simulating gene 5
# prod_rate_U mean: 0.7280, decay_U mean: 0.7358
# prod_rate_S mean: 0.7358, decay_S mean: 0.6849
#
# Simulating gene 6
# prod_rate_U mean: 2.0431, decay_U mean: 2.0130
# prod_rate_S mean: 2.0130, decay_S mean: 1.8485
#
# Simulating gene 7
# prod_rate_U mean: 1.3682, decay_U mean: 1.3747
# prod_rate_S mean: 1.3747, decay_S mean: 1.7008
#
# Simulating gene 8
# prod_rate_U mean: 2.0404, decay_U mean: 2.0359
# prod_rate_S mean: 2.0359, decay_S mean: 1.8227
#
# Simulating gene 9
# prod_rate_U mean: 2.4743, decay_U mean: 2.4291
# prod_rate_S mean: 2.4291, decay_S mean: 2.1224
# Step 1448: Converged = True
# Convergence reached at step 1448, total steps recorded: 1450.0
# Resume after convergence: True
#
# --- Iteration step: 1449 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5091
# prod_rate_S mean: 0.5091, decay_S mean: 0.7194
#
# Simulating gene 1
# prod_rate_U mean: 1.0889, decay_U mean: 1.0814
# prod_rate_S mean: 1.0814, decay_S mean: 1.1623
#
# Simulating gene 2
# prod_rate_U mean: 0.7317, decay_U mean: 0.7169
# prod_rate_S mean: 0.7169, decay_S mean: 0.6751
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9597
# prod_rate_S mean: 1.9597, decay_S mean: 2.0570
#
# Simulating gene 4
# prod_rate_U mean: 3.5357, decay_U mean: 3.5609
# prod_rate_S mean: 3.5609, decay_S mean: 3.8031
#
# Simulating gene 5
# prod_rate_U mean: 0.7283, decay_U mean: 0.7353
# prod_rate_S mean: 0.7353, decay_S mean: 0.6849
#
# Simulating gene 6
# prod_rate_U mean: 2.0439, decay_U mean: 2.0146
# prod_rate_S mean: 2.0146, decay_S mean: 1.8490
#
# Simulating gene 7
# prod_rate_U mean: 1.3670, decay_U mean: 1.3732
# prod_rate_S mean: 1.3732, decay_S mean: 1.7001
#
# Simulating gene 8
# prod_rate_U mean: 2.0429, decay_U mean: 2.0378
# prod_rate_S mean: 2.0378, decay_S mean: 1.8230
#
# Simulating gene 9
# prod_rate_U mean: 2.4726, decay_U mean: 2.4323
# prod_rate_S mean: 2.4323, decay_S mean: 2.1230
# Step 1449: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1450 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5108
# prod_rate_S mean: 0.5108, decay_S mean: 0.7190
#
# Simulating gene 1
# prod_rate_U mean: 1.0886, decay_U mean: 1.0788
# prod_rate_S mean: 1.0788, decay_S mean: 1.1624
#
# Simulating gene 2
# prod_rate_U mean: 0.7318, decay_U mean: 0.7172
# prod_rate_S mean: 0.7172, decay_S mean: 0.6752
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9594
# prod_rate_S mean: 1.9594, decay_S mean: 2.0565
#
# Simulating gene 4
# prod_rate_U mean: 3.5349, decay_U mean: 3.5590
# prod_rate_S mean: 3.5590, decay_S mean: 3.8029
#
# Simulating gene 5
# prod_rate_U mean: 0.7282, decay_U mean: 0.7360
# prod_rate_S mean: 0.7360, decay_S mean: 0.6850
#
# Simulating gene 6
# prod_rate_U mean: 2.0394, decay_U mean: 2.0169
# prod_rate_S mean: 2.0169, decay_S mean: 1.8494
#
# Simulating gene 7
# prod_rate_U mean: 1.3661, decay_U mean: 1.3748
# prod_rate_S mean: 1.3748, decay_S mean: 1.6994
#
# Simulating gene 8
# prod_rate_U mean: 2.0439, decay_U mean: 2.0362
# prod_rate_S mean: 2.0362, decay_S mean: 1.8234
#
# Simulating gene 9
# prod_rate_U mean: 2.4730, decay_U mean: 2.4366
# prod_rate_S mean: 2.4366, decay_S mean: 2.1235
# Step 1450: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1451 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5102
# prod_rate_S mean: 0.5102, decay_S mean: 0.7187
#
# Simulating gene 1
# prod_rate_U mean: 1.0894, decay_U mean: 1.0787
# prod_rate_S mean: 1.0787, decay_S mean: 1.1622
#
# Simulating gene 2
# prod_rate_U mean: 0.7307, decay_U mean: 0.7176
# prod_rate_S mean: 0.7176, decay_S mean: 0.6754
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9603
# prod_rate_S mean: 1.9603, decay_S mean: 2.0562
#
# Simulating gene 4
# prod_rate_U mean: 3.5319, decay_U mean: 3.5597
# prod_rate_S mean: 3.5597, decay_S mean: 3.8023
#
# Simulating gene 5
# prod_rate_U mean: 0.7283, decay_U mean: 0.7343
# prod_rate_S mean: 0.7343, decay_S mean: 0.6849
#
# Simulating gene 6
# prod_rate_U mean: 2.0415, decay_U mean: 2.0182
# prod_rate_S mean: 2.0182, decay_S mean: 1.8497
#
# Simulating gene 7
# prod_rate_U mean: 1.3654, decay_U mean: 1.3762
# prod_rate_S mean: 1.3762, decay_S mean: 1.6990
#
# Simulating gene 8
# prod_rate_U mean: 2.0455, decay_U mean: 2.0367
# prod_rate_S mean: 2.0367, decay_S mean: 1.8238
#
# Simulating gene 9
# prod_rate_U mean: 2.4752, decay_U mean: 2.4380
# prod_rate_S mean: 2.4380, decay_S mean: 2.1241
# Step 1451: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1452 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5112
# prod_rate_S mean: 0.5112, decay_S mean: 0.7182
#
# Simulating gene 1
# prod_rate_U mean: 1.0886, decay_U mean: 1.0811
# prod_rate_S mean: 1.0811, decay_S mean: 1.1624
#
# Simulating gene 2
# prod_rate_U mean: 0.7293, decay_U mean: 0.7177
# prod_rate_S mean: 0.7177, decay_S mean: 0.6752
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9592
# prod_rate_S mean: 1.9592, decay_S mean: 2.0559
#
# Simulating gene 4
# prod_rate_U mean: 3.5364, decay_U mean: 3.5585
# prod_rate_S mean: 3.5585, decay_S mean: 3.8017
#
# Simulating gene 5
# prod_rate_U mean: 0.7276, decay_U mean: 0.7352
# prod_rate_S mean: 0.7352, decay_S mean: 0.6850
#
# Simulating gene 6
# prod_rate_U mean: 2.0407, decay_U mean: 2.0206
# prod_rate_S mean: 2.0206, decay_S mean: 1.8500
#
# Simulating gene 7
# prod_rate_U mean: 1.3662, decay_U mean: 1.3775
# prod_rate_S mean: 1.3775, decay_S mean: 1.6980
#
# Simulating gene 8
# prod_rate_U mean: 2.0445, decay_U mean: 2.0384
# prod_rate_S mean: 2.0384, decay_S mean: 1.8241
#
# Simulating gene 9
# prod_rate_U mean: 2.4726, decay_U mean: 2.4386
# prod_rate_S mean: 2.4386, decay_S mean: 2.1243
# Step 1452: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1453 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5109
# prod_rate_S mean: 0.5109, decay_S mean: 0.7177
#
# Simulating gene 1
# prod_rate_U mean: 1.0896, decay_U mean: 1.0837
# prod_rate_S mean: 1.0837, decay_S mean: 1.1621
#
# Simulating gene 2
# prod_rate_U mean: 0.7284, decay_U mean: 0.7167
# prod_rate_S mean: 0.7167, decay_S mean: 0.6752
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9607
# prod_rate_S mean: 1.9607, decay_S mean: 2.0558
#
# Simulating gene 4
# prod_rate_U mean: 3.5355, decay_U mean: 3.5628
# prod_rate_S mean: 3.5628, decay_S mean: 3.8014
#
# Simulating gene 5
# prod_rate_U mean: 0.7278, decay_U mean: 0.7344
# prod_rate_S mean: 0.7344, decay_S mean: 0.6850
#
# Simulating gene 6
# prod_rate_U mean: 2.0361, decay_U mean: 2.0197
# prod_rate_S mean: 2.0197, decay_S mean: 1.8499
#
# Simulating gene 7
# prod_rate_U mean: 1.3696, decay_U mean: 1.3805
# prod_rate_S mean: 1.3805, decay_S mean: 1.6973
#
# Simulating gene 8
# prod_rate_U mean: 2.0400, decay_U mean: 2.0366
# prod_rate_S mean: 2.0366, decay_S mean: 1.8248
#
# Simulating gene 9
# prod_rate_U mean: 2.4720, decay_U mean: 2.4396
# prod_rate_S mean: 2.4396, decay_S mean: 2.1252
# Step 1453: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1454 ---
#
# Simulating gene 0
# prod_rate_U mean: 0.5104, decay_U mean: 0.5112
# prod_rate_S mean: 0.5112, decay_S mean: 0.7173
#
# Simulating gene 1
# prod_rate_U mean: 1.0890, decay_U mean: 1.0854
# prod_rate_S mean: 1.0854, decay_S mean: 1.1617
#
# Simulating gene 2
# prod_rate_U mean: 0.7286, decay_U mean: 0.7161
# prod_rate_S mean: 0.7161, decay_S mean: 0.6752
#
# Simulating gene 3
# prod_rate_U mean: 1.9739, decay_U mean: 1.9596
# prod_rate_S mean: 1.9596, decay_S mean: 2.0557
#
# Simulating gene 4
# prod_rate_U mean: 3.5401, decay_U mean: 3.5620
# prod_rate_S mean: 3.5620, decay_S mean: 3.8013
#
# Simulating gene 5
# prod_rate_U mean: 0.7272, decay_U mean: 0.7328
# prod_rate_S mean: 0.7328, decay_S mean: 0.6853
#
# Simulating gene 6
# prod_rate_U mean: 2.0343, decay_U mean: 2.0144
# prod_rate_S mean: 2.0144, decay_S mean: 1.8504
#
# Simulating gene 7
# prod_rate_U mean: 1.3705, decay_U mean: 1.3808
# prod_rate_S mean: 1.3808, decay_S mean: 1.6967
#
# Simulating gene 8
# prod_rate_U mean: 2.0388, decay_U mean: 2.0366
# prod_rate_S mean: 2.0366, decay_S mean: 1.8256
#
# Simulating gene 9
# prod_rate_U mean: 2.4737, decay_U mean: 2.4412
# prod_rate_S mean: 2.4412, decay_S mean: 2.1259
# Step 1454: Converged = True
# Resume after convergence: False
# === Finished bin 3 in 86.78 seconds ===
# [[0.92941229 0.44493068 0.88470165 ... 0.74806778 0.32072645 0.68486336]
#  [0.8611896  0.75368086 1.01187122 ... 1.31802758 1.50047382 1.35254464]
#  [1.25969061 1.23853457 1.06191792 ... 1.18822581 0.64458152 0.90610782]
#  ...
#  [1.34759713 0.97443954 1.93879204 ... 2.21138121 3.02826036 1.97028298]
#  [3.12669212 3.66743781 2.51104459 ... 1.9524617  1.54245031 2.0921015 ]
#  [3.24633649 3.94297798 2.96295714 ... 2.80449677 3.32723083 2.84287092]]
# (10, 1200)
# exprU_clean shape: (10, 1200)
# exprS_clean shape: (10, 1200)
# Row 0 of exprU_clean has 1200 columns
# Row 1 of exprU_clean has 1200 columns
# Row 2 of exprU_clean has 1200 columns
# Row 3 of exprU_clean has 1200 columns
# Row 4 of exprU_clean has 1200 columns
# Row 5 of exprU_clean has 1200 columns
# Row 6 of exprU_clean has 1200 columns
# Row 7 of exprU_clean has 1200 columns
# Row 8 of exprU_clean has 1200 columns
# Row 9 of exprU_clean has 1200 columns
# Row 0 of exprS_clean has 1200 columns
# Row 1 of exprS_clean has 1200 columns
# Row 2 of exprS_clean has 1200 columns
# Row 3 of exprS_clean has 1200 columns
# Row 4 of exprS_clean has 1200 columns
# Row 5 of exprS_clean has 1200 columns
# Row 6 of exprS_clean has 1200 columns
# Row 7 of exprS_clean has 1200 columns
# Row 8 of exprS_clean has 1200 columns
# Row 9 of exprS_clean has 1200 columns

# %%
exprTotal_clean = exprU_clean + exprS_clean
print(f"exprTotal_clean shape: {exprTotal_clean.shape}")
np.savetxt('exprTotal_clean.txt', exprTotal_clean, delimiter=' ', fmt='%f')
# Out:
# exprTotal_clean shape: (10, 1200)

# %% [markdown]
# # Compute pseudotimes
#
# First create the txt file from csv to find the pseudotimes

# %%
# import os

# def csv_to_txt(input_csv, output_folder="data/output"):
#     os.makedirs(output_folder, exist_ok=True)
#     output_txt = os.path.join(output_folder, os.path.basename(input_csv).replace(".csv", ".txt"))

#     with open(input_csv, 'r') as csv_file, open(output_txt, 'w') as txt_file:
#         for line in csv_file:
#             txt_file.write(line.replace(',', ' '))

#     print(f"Saved to {output_txt}")

# # Example usage in Jupyter Notebook
# input_csv = "--"  # Change this as needed
# csv_to_txt(input_csv)

#questions for wenjun: 
#what is the meaning of all of these instances of simulated csvs? are they all for the same grn and am i supposed to simulate all of them?
#for some reason when I transform the csv to txt, it's missing a single column header due to the nature of the data  
#help me figure out wt is going on w sergio

# %%
# data = np.loadtxt( "data_linear.txt" )

#data = np.load("data_bifurcate.npy")
def analyze_txt(input_txt):
    with open(input_txt, 'r') as txt_file:
        expected_columns = None
        for i, line in enumerate(txt_file):
            columns = line.strip().split()  # Split line into columns based on spaces
            num_columns = len(columns)
            
            if expected_columns is None:
                expected_columns = num_columns  # Set initial expected columns
            
            if num_columns != expected_columns:
                print(f"Column mismatch at row {i}: expected {expected_columns}, found {num_columns}")
            
            print(f"Row {i}: {num_columns} columns")  # Print column count for each row

# Example usage
input_txt = 'exprTotal_clean.txt'  # Replace with your actual TXT file path
analyze_txt(input_txt)

data = np.loadtxt( "exprTotal_clean.txt" )
# Out:
# Row 0: 1200 columns
# Row 1: 1200 columns
# Row 2: 1200 columns
# Row 3: 1200 columns
# Row 4: 1200 columns
# Row 5: 1200 columns
# Row 6: 1200 columns
# Row 7: 1200 columns
# Row 8: 1200 columns
# Row 9: 1200 columns

# %%
data.shape
# Out:
# (10, 1200)

# %%
plt.rcParams["figure.figsize"] = (5,5)
        # PCAs:
from sklearn.decomposition import PCA
plt.rcParams["font.size"] = 24
pca = PCA(n_components=6)
Xt_all = pca.fit_transform(np.log2(data.T+1) ) 
plt.scatter(Xt_all[:,0],Xt_all[:,1], c=range(Xt_all.shape[0]) )
#         for j in range(Nt):
#             idx = range(num_cells_per_time*j, num_cells_per_time*(j+1))
#             plt.plot(Xt_all[idx,0],Xt_all[idx,1],'o-')
       
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Data')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        
plt.show()
# Out:
# /var/folders/6s/mn0cx1qn7b901qdgrbh6z_hm0000gp/T/ipykernel_86170/3084148856.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
Xt_all.shape
# Out:
# (1200, 6)

# %%
# from sklearn.cluster import KMeans
from anndata import AnnData
# num_clusters = 9  # Set the number of clusters you want for KMeans

# # Apply KMeans clustering
# kmeans = KMeans(n_clusters=num_clusters, random_state=42)
# cluster_labels = kmeans.fit_predict(Xt_all)  # Using PCA components for clustering
cluster_labels = np.zeros( (1200) )
cluster_labels[0:300] = 0
cluster_labels[300:600] = 1
cluster_labels[600:900] = 2
cluster_labels[900:1200] = 3
# cluster_labels[400:500] = 4
cluster_labels=np.int8(cluster_labels)

# %%
cluster_labels[0]
# Out:
# 0

# %% [markdown]
# Create anndata obj

# %%
num_cells = data.shape[1]
num_genes = data.shape[0]
ad = AnnData(data.T)
ad.obsm["X_umap"] = Xt_all[:,0:2]
ad.obs["celltype"] = cluster_labels

# %%
cluster_labels
# Out:
# array([0, 0, 0, ..., 3, 3, 3], dtype=int8)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
custom_xlim = (-12, 12)
custom_ylim = (-12, 12)

slingshot = Slingshot(ad, celltype_key="celltype", obsm_key="X_umap", start_node=0, debug_level='verbose')


slingshot.fit(num_epochs=1, debug_axes=axes)

# Adjust legend size
# Tuck every legend into its own upper-right corner, small and unobtrusive
for ax in axes.flatten():
    # First, see if there’s an existing Legend instance
    legend = ax.get_legend()
    if legend is not None:
        # reposition the existing legend
        legend.set_loc('upper right')
        legend.set_bbox_to_anchor((0.98, 0.98))
        legend.set_frame_on(False)
        # shrink text
        legend.set_title(legend.get_title().get_text(), prop={'size': 6})
        for txt in legend.get_texts():
            txt.set_fontsize(5)
    else:
        # fallback: no legend instance, so build one from handles/labels
        handles, labels = ax.get_legend_handles_labels()
        if handles:
            ax.legend(
                handles, labels,
                loc='upper right',
                bbox_to_anchor=(0.98, 0.98),
                frameon=False,
                fontsize=8,
                title_fontsize=10,
                borderaxespad=0.1
            )

plt.tight_layout()  # Optional: improves spacing
plt.savefig("experiments_final/num_6/slingshot_output.png", dpi=300)  # Saves the figure as a PNG with high resolution
# Out:
# /Users/JenChen/Desktop/otvelo/researchy/lib/python3.9/site-packages/pyslingshot/util.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isint(cluster_labels[0]):
# Lineages: [Lineage[0, 1], Lineage[0, 3, 2]]
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/JenChen/Desktop/otvelo/researchy/lib/python3.9/site-packages/pyslingshot/slingshot.py:333: RuntimeWarning: invalid value encountered in divide
#   cell_weights = z_prime / np.nanmax(z_prime, axis=1, keepdims=True) #rowMins(D) / D
# Reversing from leaf to root
# Averaging branch @0 with lineages: [0, 1] [<pcurvepy2.pcurve.PrincipalCurve object at 0x7fdcc8633100>, <pcurvepy2.pcurve.PrincipalCurve object at 0x7fdceea2ebb0>]
# Shrinking branch @0 with curves: [<pcurvepy2.pcurve.PrincipalCurve object at 0x7fdcc8633100>, <pcurvepy2.pcurve.PrincipalCurve object at 0x7fdceea2ebb0>]
# 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]

# %%
pseudotime = slingshot.unified_pseudotime
ad.obs["pseudotime"] = slingshot.unified_pseudotime

print(type(slingshot.unified_pseudotime))  # Check the object type
print(slingshot.unified_pseudotime.shape)  # Check its dimensions
print(slingshot.unified_pseudotime[:5])    # Print first few values
# Out:
# <class 'numpy.ndarray'>
# (1200,)
# [0.         0.         0.27538619 0.         0.        ]

# %% [markdown]
# Add splicing data to anndata object also

# %%
spliced_data = np.loadtxt("exprS_clean.txt") #spliced RNA
unspliced_data = np.loadtxt("exprU_clean.txt") #unspliced RNA

# Ensure the shape matches adata.X (genes x cells)
print(spliced_data.shape)  # Should be (num_genes, num_cells)
print(unspliced_data.shape)  # Should be (num_genes, num_cells)
print(ad.layers.keys())
# Transpose if necessary (AnnData assumes cells x genes)
if spliced_data.shape[1] == ad.n_obs and spliced_data.shape[0] == ad.n_vars:
    ad.layers["spliced"] = spliced_data.T  # Ensure it aligns with AnnData structure
    print('done w spliced')
else:
    raise ValueError("Shape mismatch! Check if genes and cells are correctly aligned.")

if unspliced_data.shape[1] == ad.n_obs and unspliced_data.shape[0] == ad.n_vars:
    ad.layers["unspliced"] = unspliced_data.T  # Ensure it aligns with AnnData structure
    print('done w unspliced')
else:
    raise ValueError("Shape mismatch! Check if genes and cells are correctly aligned.")

# Print splicing data info
print("spliced data shape:", ad.layers["spliced"].shape)
print("spliced data (first 5 genes, first 5 cells):\n", ad.layers["spliced"][:5, :5])
print("unspliced data shape:", ad.layers["unspliced"].shape)
print("unspliced data (first 5 genes, first 5 cells):\n", ad.layers["unspliced"][:5, :5])

# Print pseudotime data info
print("Pseudotime data shape:", ad.obs["pseudotime"].shape)
print("Pseudotime values (first 10 cells):\n", ad.obs["pseudotime"].head(10))
print(ad.layers.keys())
ad.write("custom_ad.h5ad")
# Out:
# (10, 1200)
# (10, 1200)
# KeysView(Layers with keys: )
# done w spliced
# done w unspliced
# spliced data shape: (1200, 10)
# spliced data (first 5 genes, first 5 cells):
#  [[ 3.494899  3.401371  4.792954  6.623949 11.711578]
#  [ 3.409511  3.50389   4.718428  7.302955 11.303706]
#  [ 3.894893  3.546312  4.281274  6.92526  11.099751]
#  [ 3.335704  3.353931  4.44273   6.94342  11.708778]
#  [ 3.431765  3.526555  4.554271  6.921972 12.0319  ]]
# unspliced data shape: (1200, 10)
# unspliced data (first 5 genes, first 5 cells):
#  [[0.929412 0.86119  1.259691 1.745884 2.87329 ]
#  [0.444931 0.753681 1.238535 1.885749 3.201318]
#  [0.884702 1.011871 1.061918 1.440698 3.459898]
#  [0.598834 0.72429  0.762411 1.980812 2.983151]
#  [1.273736 0.948928 1.120818 1.75929  2.733546]]
# Pseudotime data shape: (1200,)
# Pseudotime values (first 10 cells):
#  0    0.000000
# 1    0.000000
# 2    0.275386
# 3    0.000000
# 4    0.000000
# 5    0.102392
# 6    0.034281
# 7    0.000000
# 8    0.000000
# 9    0.000000
# Name: pseudotime, dtype: float64
# KeysView(Layers with keys: spliced, unspliced)

# %%
plt.rcParams["figure.figsize"] = (6,6)
        # PCAs:
from sklearn.decomposition import PCA
plt.rcParams["font.size"] = 24
pca = PCA()
Xt_all = pca.fit_transform(np.log2(data.T+1) ) 
# sc = plt.scatter(Xt_all[:,0],Xt_all[:,1], c=pseudotime )
sc = plt.scatter(Xt_all[:, 0], Xt_all[:, 1], c=pseudotime, cmap='viridis', s=20)

#         for j in range(Nt):
#             idx = range(num_cells_per_time*j, num_cells_per_time*(j+1))
#             plt.plot(Xt_all[idx,0],Xt_all[idx,1],'o-')
#how to keep track of which cell is corr to which branch

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Pseudotime PCA')

# Add a colorbar to show pseudotime scale
cbar = plt.colorbar(sc)
cbar.set_label('Pseudotime')

plt.tight_layout()
plt.savefig("experiments_final/num_6/pseudotime_pca_mr.png", dpi=300)  # Saves as a high-resolution PNG
plt.show()
