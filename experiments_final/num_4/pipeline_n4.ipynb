# %% [markdown]
# # Pipeline for Simulating GRNS on Sergio & Packing into Anndata object
#
# First, create the files

# %% [markdown]
# Import the necessary modules

# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
from pyslingshot import Slingshot #for simulating pseudotimes
import numpy as np
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../SERGIO'))
from SERGIO.sergio import sergio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Simulate the GRN and save the splicing data to files

# %%
df = pd.read_csv('experiments_final/num_4/perturbed_matrix.tab', sep='\t', header=None, index_col=None)
bMat = df.values
print('here')
#rows and cols correspond to genes and cells (just verify)
# 100 x (6 x 300 )
#  100 genes, 6 cell types, 6 bins of 300 cells per cell type
# DO NOT include MR in the gene count
# make sure that all cells are tab separated and that zeros are just 0
# genes that are ONLY affector genes in the grn MUST be included as MR in the MR file
sim = sergio(number_genes=10, number_bins = 5, number_sc = 300, noise_params = 0.2, decays=0.8, sampling_state = 1, noise_params_splice = 0.07, noise_type='dpd', dynamics=True, bifurcation_matrix= bMat)
sim.build_graph(input_file_taregts ='experiments_final/num_4/gene_interactions.txt', input_file_regs='experiments_final/num_4/master_regulators.txt', shared_coop_state=2)
sim.simulate_dynamics()
# final ct matrix is the sum of U and S
#spliced matrix, unspliced, sum of both, pseudotime (probs just a vector bc each element in pseudotime is 1d scalar for 1 cell)
exprU, exprS = sim.getExpressions_dynamics()
exprU_clean = np.concatenate(exprU, axis = 1)
print(exprU_clean)
print(exprU_clean.shape)

exprS_clean = np.concatenate(exprS, axis = 1)
print(f"exprU_clean shape: {exprU_clean.shape}")
print(f"exprS_clean shape: {exprS_clean.shape}")

# Print the number of columns for each row
for i, row in enumerate(exprU_clean):
    print(f"Row {i} of exprU_clean has {len(row)} columns")

for i, row in enumerate(exprS_clean):
    print(f"Row {i} of exprS_clean has {len(row)} columns")

# Optionally save to text files
np.savetxt('exprU_clean.txt', exprU_clean, delimiter=' ', fmt='%f')
np.savetxt('exprS_clean.txt', exprS_clean, delimiter=' ', fmt='%f')
# Out:
# here
# bindict
#
# === Starting bin 0 ===
#
# === Starting simulation for binID: 0 ===
# Number of initial cells: 19
#
#
# --- Iteration step: 0 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3327
# prod_rate_S mean: 3.3327, decay_S mean: 3.2483
#
# Simulating gene 1
# prod_rate_U mean: 1.0043, decay_U mean: 0.9801
# prod_rate_S mean: 0.9801, decay_S mean: 1.0126
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1168
# prod_rate_S mean: 1.1168, decay_S mean: 1.1271
#
# Simulating gene 3
# prod_rate_U mean: 0.8294, decay_U mean: 0.8454
# prod_rate_S mean: 0.8454, decay_S mean: 0.8214
#
# Simulating gene 4
# prod_rate_U mean: 3.0904, decay_U mean: 3.0965
# prod_rate_S mean: 3.0965, decay_S mean: 3.1600
#
# Simulating gene 5
# prod_rate_U mean: 1.3638, decay_U mean: 1.3891
# prod_rate_S mean: 1.3891, decay_S mean: 1.3864
#
# Simulating gene 6
# prod_rate_U mean: 0.2884, decay_U mean: 0.2888
# prod_rate_S mean: 0.2888, decay_S mean: 0.2796
#
# Simulating gene 7
# prod_rate_U mean: 0.8034, decay_U mean: 0.8269
# prod_rate_S mean: 0.8269, decay_S mean: 0.8231
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8910
# prod_rate_S mean: 0.8910, decay_S mean: 0.8892
#
# Simulating gene 9
# prod_rate_U mean: 0.9667, decay_U mean: 0.9460
# prod_rate_S mean: 0.9460, decay_S mean: 0.9441
# Step 0: Converged = False
#
# --- Iteration step: 1 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3365
# prod_rate_S mean: 3.3365, decay_S mean: 3.2485
#
# Simulating gene 1
# prod_rate_U mean: 1.0083, decay_U mean: 0.9811
# prod_rate_S mean: 0.9811, decay_S mean: 1.0139
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1199
# prod_rate_S mean: 1.1199, decay_S mean: 1.1267
#
# Simulating gene 3
# prod_rate_U mean: 0.8327, decay_U mean: 0.8487
# prod_rate_S mean: 0.8487, decay_S mean: 0.8217
#
# Simulating gene 4
# prod_rate_U mean: 3.0847, decay_U mean: 3.1050
# prod_rate_S mean: 3.1050, decay_S mean: 3.1595
#
# Simulating gene 5
# prod_rate_U mean: 1.3592, decay_U mean: 1.3952
# prod_rate_S mean: 1.3952, decay_S mean: 1.3871
#
# Simulating gene 6
# prod_rate_U mean: 0.2885, decay_U mean: 0.2875
# prod_rate_S mean: 0.2875, decay_S mean: 0.2799
#
# Simulating gene 7
# prod_rate_U mean: 0.8087, decay_U mean: 0.8381
# prod_rate_S mean: 0.8381, decay_S mean: 0.8231
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8825
# prod_rate_S mean: 0.8825, decay_S mean: 0.8897
#
# Simulating gene 9
# prod_rate_U mean: 0.9648, decay_U mean: 0.9422
# prod_rate_S mean: 0.9422, decay_S mean: 0.9440
# Step 1: Converged = False
#
# --- Iteration step: 2 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3522
# prod_rate_S mean: 3.3522, decay_S mean: 3.2489
#
# Simulating gene 1
# prod_rate_U mean: 1.0083, decay_U mean: 0.9889
# prod_rate_S mean: 0.9889, decay_S mean: 1.0134
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1307
# prod_rate_S mean: 1.1307, decay_S mean: 1.1267
#
# Simulating gene 3
# prod_rate_U mean: 0.8327, decay_U mean: 0.8443
# prod_rate_S mean: 0.8443, decay_S mean: 0.8219
#
# Simulating gene 4
# prod_rate_U mean: 3.0908, decay_U mean: 3.0973
# prod_rate_S mean: 3.0973, decay_S mean: 3.1583
#
# Simulating gene 5
# prod_rate_U mean: 1.3621, decay_U mean: 1.3955
# prod_rate_S mean: 1.3955, decay_S mean: 1.3873
#
# Simulating gene 6
# prod_rate_U mean: 0.2886, decay_U mean: 0.2872
# prod_rate_S mean: 0.2872, decay_S mean: 0.2799
#
# Simulating gene 7
# prod_rate_U mean: 0.8128, decay_U mean: 0.8436
# prod_rate_S mean: 0.8436, decay_S mean: 0.8231
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8848
# prod_rate_S mean: 0.8848, decay_S mean: 0.8892
#
# Simulating gene 9
# prod_rate_U mean: 0.9552, decay_U mean: 0.9435
# prod_rate_S mean: 0.9435, decay_S mean: 0.9438
# Step 2: Converged = False
#
# --- Iteration step: 3 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3518
# prod_rate_S mean: 3.3518, decay_S mean: 3.2475
#
# Simulating gene 1
# prod_rate_U mean: 1.0054, decay_U mean: 0.9857
# prod_rate_S mean: 0.9857, decay_S mean: 1.0133
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1366
# prod_rate_S mean: 1.1366, decay_S mean: 1.1276
#
# Simulating gene 3
# prod_rate_U mean: 0.8303, decay_U mean: 0.8411
# prod_rate_S mean: 0.8411, decay_S mean: 0.8221
#
# Simulating gene 4
# prod_rate_U mean: 3.0958, decay_U mean: 3.1022
# prod_rate_S mean: 3.1022, decay_S mean: 3.1599
#
# Simulating gene 5
# prod_rate_U mean: 1.3604, decay_U mean: 1.3961
# prod_rate_S mean: 1.3961, decay_S mean: 1.3870
#
# Simulating gene 6
# prod_rate_U mean: 0.2904, decay_U mean: 0.2852
# prod_rate_S mean: 0.2852, decay_S mean: 0.2801
#
# Simulating gene 7
# prod_rate_U mean: 0.8137, decay_U mean: 0.8438
# prod_rate_S mean: 0.8438, decay_S mean: 0.8229
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8836
# prod_rate_S mean: 0.8836, decay_S mean: 0.8887
#
# Simulating gene 9
# prod_rate_U mean: 0.9365, decay_U mean: 0.9483
# prod_rate_S mean: 0.9483, decay_S mean: 0.9435
# Step 3: Converged = False
#
# --- Iteration step: 4 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3407
# prod_rate_S mean: 3.3407, decay_S mean: 3.2491
#
# Simulating gene 1
# prod_rate_U mean: 1.0040, decay_U mean: 0.9846
# prod_rate_S mean: 0.9846, decay_S mean: 1.0136
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1322
# prod_rate_S mean: 1.1322, decay_S mean: 1.1284
#
# Simulating gene 3
# prod_rate_U mean: 0.8291, decay_U mean: 0.8410
# prod_rate_S mean: 0.8410, decay_S mean: 0.8218
#
# Simulating gene 4
# prod_rate_U mean: 3.1013, decay_U mean: 3.0994
# prod_rate_S mean: 3.0994, decay_S mean: 3.1603
#
# Simulating gene 5
# prod_rate_U mean: 1.3584, decay_U mean: 1.4020
# prod_rate_S mean: 1.4020, decay_S mean: 1.3876
#
# Simulating gene 6
# prod_rate_U mean: 0.2911, decay_U mean: 0.2814
# prod_rate_S mean: 0.2814, decay_S mean: 0.2800
#
# Simulating gene 7
# prod_rate_U mean: 0.8176, decay_U mean: 0.8413
# prod_rate_S mean: 0.8413, decay_S mean: 0.8229
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8769
# prod_rate_S mean: 0.8769, decay_S mean: 0.8890
#
# Simulating gene 9
# prod_rate_U mean: 0.9259, decay_U mean: 0.9497
# prod_rate_S mean: 0.9497, decay_S mean: 0.9438
# Step 4: Converged = False
#
# --- Iteration step: 5 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3352
# prod_rate_S mean: 3.3352, decay_S mean: 3.2501
#
# Simulating gene 1
# prod_rate_U mean: 1.0019, decay_U mean: 0.9864
# prod_rate_S mean: 0.9864, decay_S mean: 1.0137
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1268
# prod_rate_S mean: 1.1268, decay_S mean: 1.1277
#
# Simulating gene 3
# prod_rate_U mean: 0.8274, decay_U mean: 0.8382
# prod_rate_S mean: 0.8382, decay_S mean: 0.8218
#
# Simulating gene 4
# prod_rate_U mean: 3.1031, decay_U mean: 3.0958
# prod_rate_S mean: 3.0958, decay_S mean: 3.1605
#
# Simulating gene 5
# prod_rate_U mean: 1.3539, decay_U mean: 1.4045
# prod_rate_S mean: 1.4045, decay_S mean: 1.3869
#
# Simulating gene 6
# prod_rate_U mean: 0.2903, decay_U mean: 0.2792
# prod_rate_S mean: 0.2792, decay_S mean: 0.2803
#
# Simulating gene 7
# prod_rate_U mean: 0.8124, decay_U mean: 0.8439
# prod_rate_S mean: 0.8439, decay_S mean: 0.8227
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8815
# prod_rate_S mean: 0.8815, decay_S mean: 0.8884
#
# Simulating gene 9
# prod_rate_U mean: 0.9585, decay_U mean: 0.9422
# prod_rate_S mean: 0.9422, decay_S mean: 0.9447
# Step 5: Converged = False
#
# --- Iteration step: 6 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3272
# prod_rate_S mean: 3.3272, decay_S mean: 3.2508
#
# Simulating gene 1
# prod_rate_U mean: 1.0023, decay_U mean: 0.9744
# prod_rate_S mean: 0.9744, decay_S mean: 1.0136
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1178
# prod_rate_S mean: 1.1178, decay_S mean: 1.1280
#
# Simulating gene 3
# prod_rate_U mean: 0.8277, decay_U mean: 0.8434
# prod_rate_S mean: 0.8434, decay_S mean: 0.8222
#
# Simulating gene 4
# prod_rate_U mean: 3.1131, decay_U mean: 3.0886
# prod_rate_S mean: 3.0886, decay_S mean: 3.1591
#
# Simulating gene 5
# prod_rate_U mean: 1.3635, decay_U mean: 1.4020
# prod_rate_S mean: 1.4020, decay_S mean: 1.3863
#
# Simulating gene 6
# prod_rate_U mean: 0.2909, decay_U mean: 0.2859
# prod_rate_S mean: 0.2859, decay_S mean: 0.2802
#
# Simulating gene 7
# prod_rate_U mean: 0.8185, decay_U mean: 0.8466
# prod_rate_S mean: 0.8466, decay_S mean: 0.8227
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8811
# prod_rate_S mean: 0.8811, decay_S mean: 0.8883
#
# Simulating gene 9
# prod_rate_U mean: 0.9491, decay_U mean: 0.9313
# prod_rate_S mean: 0.9313, decay_S mean: 0.9445
# Step 6: Converged = False
#
# --- Iteration step: 7 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3284
# prod_rate_S mean: 3.3284, decay_S mean: 3.2508
#
# Simulating gene 1
# prod_rate_U mean: 1.0025, decay_U mean: 0.9801
# prod_rate_S mean: 0.9801, decay_S mean: 1.0135
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1214
# prod_rate_S mean: 1.1214, decay_S mean: 1.1279
#
# Simulating gene 3
# prod_rate_U mean: 0.8279, decay_U mean: 0.8391
# prod_rate_S mean: 0.8391, decay_S mean: 0.8214
#
# Simulating gene 4
# prod_rate_U mean: 3.1285, decay_U mean: 3.1045
# prod_rate_S mean: 3.1045, decay_S mean: 3.1607
#
# Simulating gene 5
# prod_rate_U mean: 1.3571, decay_U mean: 1.4043
# prod_rate_S mean: 1.4043, decay_S mean: 1.3858
#
# Simulating gene 6
# prod_rate_U mean: 0.2954, decay_U mean: 0.2840
# prod_rate_S mean: 0.2840, decay_S mean: 0.2805
#
# Simulating gene 7
# prod_rate_U mean: 0.8252, decay_U mean: 0.8442
# prod_rate_S mean: 0.8442, decay_S mean: 0.8224
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8794
# prod_rate_S mean: 0.8794, decay_S mean: 0.8881
#
# Simulating gene 9
# prod_rate_U mean: 0.9476, decay_U mean: 0.9315
# prod_rate_S mean: 0.9315, decay_S mean: 0.9440
# Step 7: Converged = False
#
# --- Iteration step: 8 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3288
# prod_rate_S mean: 3.3288, decay_S mean: 3.2509
#
# Simulating gene 1
# prod_rate_U mean: 1.0014, decay_U mean: 0.9823
# prod_rate_S mean: 0.9823, decay_S mean: 1.0135
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1179
# prod_rate_S mean: 1.1179, decay_S mean: 1.1275
#
# Simulating gene 3
# prod_rate_U mean: 0.8270, decay_U mean: 0.8335
# prod_rate_S mean: 0.8335, decay_S mean: 0.8218
#
# Simulating gene 4
# prod_rate_U mean: 3.1314, decay_U mean: 3.0940
# prod_rate_S mean: 3.0940, decay_S mean: 3.1603
#
# Simulating gene 5
# prod_rate_U mean: 1.3617, decay_U mean: 1.4199
# prod_rate_S mean: 1.4199, decay_S mean: 1.3863
#
# Simulating gene 6
# prod_rate_U mean: 0.2976, decay_U mean: 0.2837
# prod_rate_S mean: 0.2837, decay_S mean: 0.2803
#
# Simulating gene 7
# prod_rate_U mean: 0.8239, decay_U mean: 0.8446
# prod_rate_S mean: 0.8446, decay_S mean: 0.8229
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8836
# prod_rate_S mean: 0.8836, decay_S mean: 0.8887
#
# Simulating gene 9
# prod_rate_U mean: 0.9604, decay_U mean: 0.9379
# prod_rate_S mean: 0.9379, decay_S mean: 0.9444
# Step 8: Converged = False
#
# --- Iteration step: 9 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3249
# prod_rate_S mean: 3.3249, decay_S mean: 3.2514
#
# Simulating gene 1
# prod_rate_U mean: 1.0002, decay_U mean: 0.9898
# prod_rate_S mean: 0.9898, decay_S mean: 1.0129
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1163
# prod_rate_S mean: 1.1163, decay_S mean: 1.1278
#
# Simulating gene 3
# prod_rate_U mean: 0.8260, decay_U mean: 0.8352
# prod_rate_S mean: 0.8352, decay_S mean: 0.8219
#
# Simulating gene 4
# prod_rate_U mean: 3.1285, decay_U mean: 3.1015
# prod_rate_S mean: 3.1015, decay_S mean: 3.1602
#
# Simulating gene 5
# prod_rate_U mean: 1.3632, decay_U mean: 1.4277
# prod_rate_S mean: 1.4277, decay_S mean: 1.3861
#
# Simulating gene 6
# prod_rate_U mean: 0.2966, decay_U mean: 0.2863
# prod_rate_S mean: 0.2863, decay_S mean: 0.2807
#
# Simulating gene 7
# prod_rate_U mean: 0.8210, decay_U mean: 0.8475
# prod_rate_S mean: 0.8475, decay_S mean: 0.8228
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8838
# prod_rate_S mean: 0.8838, decay_S mean: 0.8885
#
# Simulating gene 9
# prod_rate_U mean: 0.9516, decay_U mean: 0.9451
# prod_rate_S mean: 0.9451, decay_S mean: 0.9445
# Step 9: Converged = False
#
# --- Iteration step: 10 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3207
# prod_rate_S mean: 3.3207, decay_S mean: 3.2525
#
# Simulating gene 1
# prod_rate_U mean: 0.9990, decay_U mean: 0.9907
# prod_rate_S mean: 0.9907, decay_S mean: 1.0129
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1132
# prod_rate_S mean: 1.1132, decay_S mean: 1.1279
#
# Simulating gene 3
# prod_rate_U mean: 0.8250, decay_U mean: 0.8376
# prod_rate_S mean: 0.8376, decay_S mean: 0.8216
#
# Simulating gene 4
# prod_rate_U mean: 3.1246, decay_U mean: 3.1043
# prod_rate_S mean: 3.1043, decay_S mean: 3.1607
#
# Simulating gene 5
# prod_rate_U mean: 1.3593, decay_U mean: 1.4246
# prod_rate_S mean: 1.4246, decay_S mean: 1.3867
#
# Simulating gene 6
# prod_rate_U mean: 0.2971, decay_U mean: 0.2845
# prod_rate_S mean: 0.2845, decay_S mean: 0.2810
#
# Simulating gene 7
# prod_rate_U mean: 0.8192, decay_U mean: 0.8495
# prod_rate_S mean: 0.8495, decay_S mean: 0.8232
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8777
# prod_rate_S mean: 0.8777, decay_S mean: 0.8893
#
# Simulating gene 9
# prod_rate_U mean: 0.9378, decay_U mean: 0.9424
# prod_rate_S mean: 0.9424, decay_S mean: 0.9444
# Step 10: Converged = False
#
# --- Iteration step: 11 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3150
# prod_rate_S mean: 3.3150, decay_S mean: 3.2518
#
# Simulating gene 1
# prod_rate_U mean: 0.9985, decay_U mean: 0.9949
# prod_rate_S mean: 0.9949, decay_S mean: 1.0133
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1074
# prod_rate_S mean: 1.1074, decay_S mean: 1.1270
#
# Simulating gene 3
# prod_rate_U mean: 0.8246, decay_U mean: 0.8397
# prod_rate_S mean: 0.8397, decay_S mean: 0.8224
#
# Simulating gene 4
# prod_rate_U mean: 3.1272, decay_U mean: 3.0978
# prod_rate_S mean: 3.0978, decay_S mean: 3.1586
#
# Simulating gene 5
# prod_rate_U mean: 1.3536, decay_U mean: 1.4266
# prod_rate_S mean: 1.4266, decay_S mean: 1.3872
#
# Simulating gene 6
# prod_rate_U mean: 0.2940, decay_U mean: 0.2817
# prod_rate_S mean: 0.2817, decay_S mean: 0.2815
#
# Simulating gene 7
# prod_rate_U mean: 0.8227, decay_U mean: 0.8482
# prod_rate_S mean: 0.8482, decay_S mean: 0.8225
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8720
# prod_rate_S mean: 0.8720, decay_S mean: 0.8897
#
# Simulating gene 9
# prod_rate_U mean: 0.9551, decay_U mean: 0.9442
# prod_rate_S mean: 0.9442, decay_S mean: 0.9447
# Step 11: Converged = False
#
# --- Iteration step: 12 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3150
# prod_rate_S mean: 3.3150, decay_S mean: 3.2533
#
# Simulating gene 1
# prod_rate_U mean: 1.0007, decay_U mean: 0.9840
# prod_rate_S mean: 0.9840, decay_S mean: 1.0127
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1068
# prod_rate_S mean: 1.1068, decay_S mean: 1.1267
#
# Simulating gene 3
# prod_rate_U mean: 0.8264, decay_U mean: 0.8375
# prod_rate_S mean: 0.8375, decay_S mean: 0.8223
#
# Simulating gene 4
# prod_rate_U mean: 3.1292, decay_U mean: 3.0884
# prod_rate_S mean: 3.0884, decay_S mean: 3.1588
#
# Simulating gene 5
# prod_rate_U mean: 1.3614, decay_U mean: 1.4154
# prod_rate_S mean: 1.4154, decay_S mean: 1.3879
#
# Simulating gene 6
# prod_rate_U mean: 0.2952, decay_U mean: 0.2852
# prod_rate_S mean: 0.2852, decay_S mean: 0.2814
#
# Simulating gene 7
# prod_rate_U mean: 0.8241, decay_U mean: 0.8489
# prod_rate_S mean: 0.8489, decay_S mean: 0.8227
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8723
# prod_rate_S mean: 0.8723, decay_S mean: 0.8901
#
# Simulating gene 9
# prod_rate_U mean: 0.9444, decay_U mean: 0.9451
# prod_rate_S mean: 0.9451, decay_S mean: 0.9441
# Step 12: Converged = False
#
# --- Iteration step: 13 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3234
# prod_rate_S mean: 3.3234, decay_S mean: 3.2532
#
# Simulating gene 1
# prod_rate_U mean: 0.9986, decay_U mean: 0.9892
# prod_rate_S mean: 0.9892, decay_S mean: 1.0127
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1081
# prod_rate_S mean: 1.1081, decay_S mean: 1.1262
#
# Simulating gene 3
# prod_rate_U mean: 0.8247, decay_U mean: 0.8361
# prod_rate_S mean: 0.8361, decay_S mean: 0.8222
#
# Simulating gene 4
# prod_rate_U mean: 3.1172, decay_U mean: 3.1014
# prod_rate_S mean: 3.1014, decay_S mean: 3.1575
#
# Simulating gene 5
# prod_rate_U mean: 1.3617, decay_U mean: 1.4196
# prod_rate_S mean: 1.4196, decay_S mean: 1.3886
#
# Simulating gene 6
# prod_rate_U mean: 0.2968, decay_U mean: 0.2831
# prod_rate_S mean: 0.2831, decay_S mean: 0.2812
#
# Simulating gene 7
# prod_rate_U mean: 0.8182, decay_U mean: 0.8521
# prod_rate_S mean: 0.8521, decay_S mean: 0.8222
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8767
# prod_rate_S mean: 0.8767, decay_S mean: 0.8903
#
# Simulating gene 9
# prod_rate_U mean: 0.9466, decay_U mean: 0.9469
# prod_rate_S mean: 0.9469, decay_S mean: 0.9434
# Step 13: Converged = False
#
# --- Iteration step: 14 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3163
# prod_rate_S mean: 3.3163, decay_S mean: 3.2519
#
# Simulating gene 1
# prod_rate_U mean: 0.9990, decay_U mean: 0.9948
# prod_rate_S mean: 0.9948, decay_S mean: 1.0129
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1142
# prod_rate_S mean: 1.1142, decay_S mean: 1.1256
#
# Simulating gene 3
# prod_rate_U mean: 0.8250, decay_U mean: 0.8420
# prod_rate_S mean: 0.8420, decay_S mean: 0.8227
#
# Simulating gene 4
# prod_rate_U mean: 3.1018, decay_U mean: 3.1020
# prod_rate_S mean: 3.1020, decay_S mean: 3.1583
#
# Simulating gene 5
# prod_rate_U mean: 1.3620, decay_U mean: 1.4254
# prod_rate_S mean: 1.4254, decay_S mean: 1.3889
#
# Simulating gene 6
# prod_rate_U mean: 0.2956, decay_U mean: 0.2835
# prod_rate_S mean: 0.2835, decay_S mean: 0.2811
#
# Simulating gene 7
# prod_rate_U mean: 0.8154, decay_U mean: 0.8525
# prod_rate_S mean: 0.8525, decay_S mean: 0.8225
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8758
# prod_rate_S mean: 0.8758, decay_S mean: 0.8897
#
# Simulating gene 9
# prod_rate_U mean: 0.9639, decay_U mean: 0.9415
# prod_rate_S mean: 0.9415, decay_S mean: 0.9433
# Step 14: Converged = False
#
# --- Iteration step: 15 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3179
# prod_rate_S mean: 3.3179, decay_S mean: 3.2531
#
# Simulating gene 1
# prod_rate_U mean: 0.9965, decay_U mean: 0.9935
# prod_rate_S mean: 0.9935, decay_S mean: 1.0133
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1237
# prod_rate_S mean: 1.1237, decay_S mean: 1.1262
#
# Simulating gene 3
# prod_rate_U mean: 0.8229, decay_U mean: 0.8456
# prod_rate_S mean: 0.8456, decay_S mean: 0.8223
#
# Simulating gene 4
# prod_rate_U mean: 3.1271, decay_U mean: 3.1033
# prod_rate_S mean: 3.1033, decay_S mean: 3.1580
#
# Simulating gene 5
# prod_rate_U mean: 1.3624, decay_U mean: 1.4213
# prod_rate_S mean: 1.4213, decay_S mean: 1.3891
#
# Simulating gene 6
# prod_rate_U mean: 0.2945, decay_U mean: 0.2871
# prod_rate_S mean: 0.2871, decay_S mean: 0.2812
#
# Simulating gene 7
# prod_rate_U mean: 0.8250, decay_U mean: 0.8478
# prod_rate_S mean: 0.8478, decay_S mean: 0.8222
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8721
# prod_rate_S mean: 0.8721, decay_S mean: 0.8900
#
# Simulating gene 9
# prod_rate_U mean: 0.9832, decay_U mean: 0.9350
# prod_rate_S mean: 0.9350, decay_S mean: 0.9438
# Step 15: Converged = False
#
# --- Iteration step: 16 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.3090
# prod_rate_S mean: 3.3090, decay_S mean: 3.2535
#
# Simulating gene 1
# prod_rate_U mean: 0.9936, decay_U mean: 1.0003
# prod_rate_S mean: 1.0003, decay_S mean: 1.0137
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1143
# prod_rate_S mean: 1.1143, decay_S mean: 1.1265
#
# Simulating gene 3
# prod_rate_U mean: 0.8206, decay_U mean: 0.8380
# prod_rate_S mean: 0.8380, decay_S mean: 0.8221
#
# Simulating gene 4
# prod_rate_U mean: 3.1008, decay_U mean: 3.1037
# prod_rate_S mean: 3.1037, decay_S mean: 3.1585
#
# Simulating gene 5
# prod_rate_U mean: 1.3638, decay_U mean: 1.4172
# prod_rate_S mean: 1.4172, decay_S mean: 1.3888
#
# Simulating gene 6
# prod_rate_U mean: 0.2921, decay_U mean: 0.2911
# prod_rate_S mean: 0.2911, decay_S mean: 0.2809
#
# Simulating gene 7
# prod_rate_U mean: 0.8179, decay_U mean: 0.8439
# prod_rate_S mean: 0.8439, decay_S mean: 0.8221
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8673
# prod_rate_S mean: 0.8673, decay_S mean: 0.8896
#
# Simulating gene 9
# prod_rate_U mean: 0.9872, decay_U mean: 0.9339
# prod_rate_S mean: 0.9339, decay_S mean: 0.9436
# Step 16: Converged = False
#
# --- Iteration step: 17 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2971
# prod_rate_S mean: 3.2971, decay_S mean: 3.2528
#
# Simulating gene 1
# prod_rate_U mean: 0.9937, decay_U mean: 0.9944
# prod_rate_S mean: 0.9944, decay_S mean: 1.0133
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1219
# prod_rate_S mean: 1.1219, decay_S mean: 1.1269
#
# Simulating gene 3
# prod_rate_U mean: 0.8206, decay_U mean: 0.8457
# prod_rate_S mean: 0.8457, decay_S mean: 0.8221
#
# Simulating gene 4
# prod_rate_U mean: 3.0991, decay_U mean: 3.1059
# prod_rate_S mean: 3.1059, decay_S mean: 3.1591
#
# Simulating gene 5
# prod_rate_U mean: 1.3644, decay_U mean: 1.4088
# prod_rate_S mean: 1.4088, decay_S mean: 1.3897
#
# Simulating gene 6
# prod_rate_U mean: 0.2905, decay_U mean: 0.2919
# prod_rate_S mean: 0.2919, decay_S mean: 0.2804
#
# Simulating gene 7
# prod_rate_U mean: 0.8185, decay_U mean: 0.8449
# prod_rate_S mean: 0.8449, decay_S mean: 0.8223
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8691
# prod_rate_S mean: 0.8691, decay_S mean: 0.8899
#
# Simulating gene 9
# prod_rate_U mean: 0.9644, decay_U mean: 0.9462
# prod_rate_S mean: 0.9462, decay_S mean: 0.9437
# Step 17: Converged = False
#
# --- Iteration step: 18 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2992
# prod_rate_S mean: 3.2992, decay_S mean: 3.2531
#
# Simulating gene 1
# prod_rate_U mean: 0.9914, decay_U mean: 0.9900
# prod_rate_S mean: 0.9900, decay_S mean: 1.0138
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1281
# prod_rate_S mean: 1.1281, decay_S mean: 1.1261
#
# Simulating gene 3
# prod_rate_U mean: 0.8188, decay_U mean: 0.8447
# prod_rate_S mean: 0.8447, decay_S mean: 0.8223
#
# Simulating gene 4
# prod_rate_U mean: 3.1250, decay_U mean: 3.1065
# prod_rate_S mean: 3.1065, decay_S mean: 3.1592
#
# Simulating gene 5
# prod_rate_U mean: 1.3612, decay_U mean: 1.4035
# prod_rate_S mean: 1.4035, decay_S mean: 1.3903
#
# Simulating gene 6
# prod_rate_U mean: 0.2938, decay_U mean: 0.2872
# prod_rate_S mean: 0.2872, decay_S mean: 0.2805
#
# Simulating gene 7
# prod_rate_U mean: 0.8269, decay_U mean: 0.8444
# prod_rate_S mean: 0.8444, decay_S mean: 0.8226
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8727
# prod_rate_S mean: 0.8727, decay_S mean: 0.8898
#
# Simulating gene 9
# prod_rate_U mean: 0.9680, decay_U mean: 0.9524
# prod_rate_S mean: 0.9524, decay_S mean: 0.9439
# Step 18: Converged = False
#
# --- Iteration step: 19 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2919
# prod_rate_S mean: 3.2919, decay_S mean: 3.2520
#
# Simulating gene 1
# prod_rate_U mean: 0.9900, decay_U mean: 0.9861
# prod_rate_S mean: 0.9861, decay_S mean: 1.0134
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1210
# prod_rate_S mean: 1.1210, decay_S mean: 1.1260
#
# Simulating gene 3
# prod_rate_U mean: 0.8176, decay_U mean: 0.8384
# prod_rate_S mean: 0.8384, decay_S mean: 0.8225
#
# Simulating gene 4
# prod_rate_U mean: 3.1210, decay_U mean: 3.1011
# prod_rate_S mean: 3.1011, decay_S mean: 3.1583
#
# Simulating gene 5
# prod_rate_U mean: 1.3652, decay_U mean: 1.4148
# prod_rate_S mean: 1.4148, decay_S mean: 1.3907
#
# Simulating gene 6
# prod_rate_U mean: 0.2937, decay_U mean: 0.2880
# prod_rate_S mean: 0.2880, decay_S mean: 0.2806
#
# Simulating gene 7
# prod_rate_U mean: 0.8294, decay_U mean: 0.8495
# prod_rate_S mean: 0.8495, decay_S mean: 0.8227
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8712
# prod_rate_S mean: 0.8712, decay_S mean: 0.8901
#
# Simulating gene 9
# prod_rate_U mean: 0.9413, decay_U mean: 0.9469
# prod_rate_S mean: 0.9469, decay_S mean: 0.9436
# Step 19: Converged = False
#
# --- Iteration step: 20 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2865
# prod_rate_S mean: 3.2865, decay_S mean: 3.2510
#
# Simulating gene 1
# prod_rate_U mean: 0.9886, decay_U mean: 0.9837
# prod_rate_S mean: 0.9837, decay_S mean: 1.0134
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1309
# prod_rate_S mean: 1.1309, decay_S mean: 1.1267
#
# Simulating gene 3
# prod_rate_U mean: 0.8164, decay_U mean: 0.8357
# prod_rate_S mean: 0.8357, decay_S mean: 0.8223
#
# Simulating gene 4
# prod_rate_U mean: 3.1422, decay_U mean: 3.1079
# prod_rate_S mean: 3.1079, decay_S mean: 3.1581
#
# Simulating gene 5
# prod_rate_U mean: 1.3545, decay_U mean: 1.4146
# prod_rate_S mean: 1.4146, decay_S mean: 1.3902
#
# Simulating gene 6
# prod_rate_U mean: 0.2921, decay_U mean: 0.2825
# prod_rate_S mean: 0.2825, decay_S mean: 0.2807
#
# Simulating gene 7
# prod_rate_U mean: 0.8334, decay_U mean: 0.8512
# prod_rate_S mean: 0.8512, decay_S mean: 0.8224
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8778
# prod_rate_S mean: 0.8778, decay_S mean: 0.8902
#
# Simulating gene 9
# prod_rate_U mean: 0.9667, decay_U mean: 0.9450
# prod_rate_S mean: 0.9450, decay_S mean: 0.9430
# Step 20: Converged = False
#
# --- Iteration step: 21 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2803
# prod_rate_S mean: 3.2803, decay_S mean: 3.2520
#
# Simulating gene 1
# prod_rate_U mean: 0.9873, decay_U mean: 0.9837
# prod_rate_S mean: 0.9837, decay_S mean: 1.0136
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1228
# prod_rate_S mean: 1.1228, decay_S mean: 1.1272
#
# Simulating gene 3
# prod_rate_U mean: 0.8153, decay_U mean: 0.8314
# prod_rate_S mean: 0.8314, decay_S mean: 0.8213
#
# Simulating gene 4
# prod_rate_U mean: 3.1265, decay_U mean: 3.0900
# prod_rate_S mean: 3.0900, decay_S mean: 3.1569
#
# Simulating gene 5
# prod_rate_U mean: 1.3553, decay_U mean: 1.4090
# prod_rate_S mean: 1.4090, decay_S mean: 1.3907
#
# Simulating gene 6
# prod_rate_U mean: 0.2899, decay_U mean: 0.2877
# prod_rate_S mean: 0.2877, decay_S mean: 0.2812
#
# Simulating gene 7
# prod_rate_U mean: 0.8273, decay_U mean: 0.8575
# prod_rate_S mean: 0.8575, decay_S mean: 0.8221
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8737
# prod_rate_S mean: 0.8737, decay_S mean: 0.8903
#
# Simulating gene 9
# prod_rate_U mean: 0.9557, decay_U mean: 0.9454
# prod_rate_S mean: 0.9454, decay_S mean: 0.9428
# Step 21: Converged = False
#
# --- Iteration step: 22 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2750
# prod_rate_S mean: 3.2750, decay_S mean: 3.2517
#
# Simulating gene 1
# prod_rate_U mean: 0.9876, decay_U mean: 0.9848
# prod_rate_S mean: 0.9848, decay_S mean: 1.0137
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1227
# prod_rate_S mean: 1.1227, decay_S mean: 1.1272
#
# Simulating gene 3
# prod_rate_U mean: 0.8156, decay_U mean: 0.8378
# prod_rate_S mean: 0.8378, decay_S mean: 0.8211
#
# Simulating gene 4
# prod_rate_U mean: 3.1230, decay_U mean: 3.0915
# prod_rate_S mean: 3.0915, decay_S mean: 3.1579
#
# Simulating gene 5
# prod_rate_U mean: 1.3640, decay_U mean: 1.4013
# prod_rate_S mean: 1.4013, decay_S mean: 1.3905
#
# Simulating gene 6
# prod_rate_U mean: 0.2906, decay_U mean: 0.2855
# prod_rate_S mean: 0.2855, decay_S mean: 0.2812
#
# Simulating gene 7
# prod_rate_U mean: 0.8261, decay_U mean: 0.8586
# prod_rate_S mean: 0.8586, decay_S mean: 0.8219
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8803
# prod_rate_S mean: 0.8803, decay_S mean: 0.8908
#
# Simulating gene 9
# prod_rate_U mean: 0.9339, decay_U mean: 0.9478
# prod_rate_S mean: 0.9478, decay_S mean: 0.9430
# Step 22: Converged = False
#
# --- Iteration step: 23 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2764
# prod_rate_S mean: 3.2764, decay_S mean: 3.2506
#
# Simulating gene 1
# prod_rate_U mean: 0.9881, decay_U mean: 0.9802
# prod_rate_S mean: 0.9802, decay_S mean: 1.0138
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1319
# prod_rate_S mean: 1.1319, decay_S mean: 1.1278
#
# Simulating gene 3
# prod_rate_U mean: 0.8161, decay_U mean: 0.8380
# prod_rate_S mean: 0.8380, decay_S mean: 0.8212
#
# Simulating gene 4
# prod_rate_U mean: 3.1260, decay_U mean: 3.1061
# prod_rate_S mean: 3.1061, decay_S mean: 3.1587
#
# Simulating gene 5
# prod_rate_U mean: 1.3639, decay_U mean: 1.4039
# prod_rate_S mean: 1.4039, decay_S mean: 1.3906
#
# Simulating gene 6
# prod_rate_U mean: 0.2909, decay_U mean: 0.2809
# prod_rate_S mean: 0.2809, decay_S mean: 0.2816
#
# Simulating gene 7
# prod_rate_U mean: 0.8269, decay_U mean: 0.8494
# prod_rate_S mean: 0.8494, decay_S mean: 0.8215
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8838
# prod_rate_S mean: 0.8838, decay_S mean: 0.8913
#
# Simulating gene 9
# prod_rate_U mean: 0.9467, decay_U mean: 0.9486
# prod_rate_S mean: 0.9486, decay_S mean: 0.9431
# Step 23: Converged = False
#
# --- Iteration step: 24 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2787
# prod_rate_S mean: 3.2787, decay_S mean: 3.2501
#
# Simulating gene 1
# prod_rate_U mean: 0.9896, decay_U mean: 0.9801
# prod_rate_S mean: 0.9801, decay_S mean: 1.0140
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1354
# prod_rate_S mean: 1.1354, decay_S mean: 1.1287
#
# Simulating gene 3
# prod_rate_U mean: 0.8173, decay_U mean: 0.8396
# prod_rate_S mean: 0.8396, decay_S mean: 0.8208
#
# Simulating gene 4
# prod_rate_U mean: 3.1105, decay_U mean: 3.1061
# prod_rate_S mean: 3.1061, decay_S mean: 3.1593
#
# Simulating gene 5
# prod_rate_U mean: 1.3701, decay_U mean: 1.4046
# prod_rate_S mean: 1.4046, decay_S mean: 1.3904
#
# Simulating gene 6
# prod_rate_U mean: 0.2919, decay_U mean: 0.2836
# prod_rate_S mean: 0.2836, decay_S mean: 0.2819
#
# Simulating gene 7
# prod_rate_U mean: 0.8247, decay_U mean: 0.8494
# prod_rate_S mean: 0.8494, decay_S mean: 0.8213
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8767
# prod_rate_S mean: 0.8767, decay_S mean: 0.8916
#
# Simulating gene 9
# prod_rate_U mean: 0.9443, decay_U mean: 0.9501
# prod_rate_S mean: 0.9501, decay_S mean: 0.9435
# Step 24: Converged = False
#
# --- Iteration step: 25 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2841
# prod_rate_S mean: 3.2841, decay_S mean: 3.2497
#
# Simulating gene 1
# prod_rate_U mean: 0.9878, decay_U mean: 0.9923
# prod_rate_S mean: 0.9923, decay_S mean: 1.0138
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1394
# prod_rate_S mean: 1.1394, decay_S mean: 1.1297
#
# Simulating gene 3
# prod_rate_U mean: 0.8158, decay_U mean: 0.8418
# prod_rate_S mean: 0.8418, decay_S mean: 0.8208
#
# Simulating gene 4
# prod_rate_U mean: 3.1234, decay_U mean: 3.1165
# prod_rate_S mean: 3.1165, decay_S mean: 3.1592
#
# Simulating gene 5
# prod_rate_U mean: 1.3697, decay_U mean: 1.4083
# prod_rate_S mean: 1.4083, decay_S mean: 1.3901
#
# Simulating gene 6
# prod_rate_U mean: 0.2920, decay_U mean: 0.2831
# prod_rate_S mean: 0.2831, decay_S mean: 0.2819
#
# Simulating gene 7
# prod_rate_U mean: 0.8312, decay_U mean: 0.8480
# prod_rate_S mean: 0.8480, decay_S mean: 0.8217
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8769
# prod_rate_S mean: 0.8769, decay_S mean: 0.8919
#
# Simulating gene 9
# prod_rate_U mean: 0.9562, decay_U mean: 0.9459
# prod_rate_S mean: 0.9459, decay_S mean: 0.9438
# Step 25: Converged = False
#
# --- Iteration step: 26 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2766
# prod_rate_S mean: 3.2766, decay_S mean: 3.2510
#
# Simulating gene 1
# prod_rate_U mean: 0.9869, decay_U mean: 0.9963
# prod_rate_S mean: 0.9963, decay_S mean: 1.0136
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1417
# prod_rate_S mean: 1.1417, decay_S mean: 1.1294
#
# Simulating gene 3
# prod_rate_U mean: 0.8150, decay_U mean: 0.8348
# prod_rate_S mean: 0.8348, decay_S mean: 0.8201
#
# Simulating gene 4
# prod_rate_U mean: 3.1208, decay_U mean: 3.1157
# prod_rate_S mean: 3.1157, decay_S mean: 3.1611
#
# Simulating gene 5
# prod_rate_U mean: 1.3671, decay_U mean: 1.4087
# prod_rate_S mean: 1.4087, decay_S mean: 1.3908
#
# Simulating gene 6
# prod_rate_U mean: 0.2924, decay_U mean: 0.2856
# prod_rate_S mean: 0.2856, decay_S mean: 0.2820
#
# Simulating gene 7
# prod_rate_U mean: 0.8308, decay_U mean: 0.8529
# prod_rate_S mean: 0.8529, decay_S mean: 0.8212
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8742
# prod_rate_S mean: 0.8742, decay_S mean: 0.8925
#
# Simulating gene 9
# prod_rate_U mean: 0.9807, decay_U mean: 0.9470
# prod_rate_S mean: 0.9470, decay_S mean: 0.9437
# Step 26: Converged = False
#
# --- Iteration step: 27 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2734
# prod_rate_S mean: 3.2734, decay_S mean: 3.2516
#
# Simulating gene 1
# prod_rate_U mean: 0.9877, decay_U mean: 0.9970
# prod_rate_S mean: 0.9970, decay_S mean: 1.0140
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1403
# prod_rate_S mean: 1.1403, decay_S mean: 1.1295
#
# Simulating gene 3
# prod_rate_U mean: 0.8157, decay_U mean: 0.8349
# prod_rate_S mean: 0.8349, decay_S mean: 0.8206
#
# Simulating gene 4
# prod_rate_U mean: 3.1176, decay_U mean: 3.1113
# prod_rate_S mean: 3.1113, decay_S mean: 3.1607
#
# Simulating gene 5
# prod_rate_U mean: 1.3709, decay_U mean: 1.4103
# prod_rate_S mean: 1.4103, decay_S mean: 1.3909
#
# Simulating gene 6
# prod_rate_U mean: 0.2938, decay_U mean: 0.2908
# prod_rate_S mean: 0.2908, decay_S mean: 0.2821
#
# Simulating gene 7
# prod_rate_U mean: 0.8263, decay_U mean: 0.8568
# prod_rate_S mean: 0.8568, decay_S mean: 0.8212
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8776
# prod_rate_S mean: 0.8776, decay_S mean: 0.8928
#
# Simulating gene 9
# prod_rate_U mean: 0.9752, decay_U mean: 0.9416
# prod_rate_S mean: 0.9416, decay_S mean: 0.9446
# Step 27: Converged = False
#
# --- Iteration step: 28 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2772
# prod_rate_S mean: 3.2772, decay_S mean: 3.2520
#
# Simulating gene 1
# prod_rate_U mean: 0.9859, decay_U mean: 0.9996
# prod_rate_S mean: 0.9996, decay_S mean: 1.0146
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1361
# prod_rate_S mean: 1.1361, decay_S mean: 1.1303
#
# Simulating gene 3
# prod_rate_U mean: 0.8142, decay_U mean: 0.8387
# prod_rate_S mean: 0.8387, decay_S mean: 0.8205
#
# Simulating gene 4
# prod_rate_U mean: 3.1140, decay_U mean: 3.1178
# prod_rate_S mean: 3.1178, decay_S mean: 3.1605
#
# Simulating gene 5
# prod_rate_U mean: 1.3722, decay_U mean: 1.4152
# prod_rate_S mean: 1.4152, decay_S mean: 1.3918
#
# Simulating gene 6
# prod_rate_U mean: 0.2894, decay_U mean: 0.2897
# prod_rate_S mean: 0.2897, decay_S mean: 0.2817
#
# Simulating gene 7
# prod_rate_U mean: 0.8232, decay_U mean: 0.8517
# prod_rate_S mean: 0.8517, decay_S mean: 0.8219
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8831
# prod_rate_S mean: 0.8831, decay_S mean: 0.8925
#
# Simulating gene 9
# prod_rate_U mean: 0.9520, decay_U mean: 0.9527
# prod_rate_S mean: 0.9527, decay_S mean: 0.9444
# Step 28: Converged = False
#
# --- Iteration step: 29 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2716
# prod_rate_S mean: 3.2716, decay_S mean: 3.2515
#
# Simulating gene 1
# prod_rate_U mean: 0.9848, decay_U mean: 1.0038
# prod_rate_S mean: 1.0038, decay_S mean: 1.0147
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1399
# prod_rate_S mean: 1.1399, decay_S mean: 1.1304
#
# Simulating gene 3
# prod_rate_U mean: 0.8132, decay_U mean: 0.8419
# prod_rate_S mean: 0.8419, decay_S mean: 0.8207
#
# Simulating gene 4
# prod_rate_U mean: 3.0983, decay_U mean: 3.1200
# prod_rate_S mean: 3.1200, decay_S mean: 3.1610
#
# Simulating gene 5
# prod_rate_U mean: 1.3753, decay_U mean: 1.3997
# prod_rate_S mean: 1.3997, decay_S mean: 1.3925
#
# Simulating gene 6
# prod_rate_U mean: 0.2882, decay_U mean: 0.2849
# prod_rate_S mean: 0.2849, decay_S mean: 0.2821
#
# Simulating gene 7
# prod_rate_U mean: 0.8173, decay_U mean: 0.8539
# prod_rate_S mean: 0.8539, decay_S mean: 0.8218
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8764
# prod_rate_S mean: 0.8764, decay_S mean: 0.8929
#
# Simulating gene 9
# prod_rate_U mean: 0.9545, decay_U mean: 0.9498
# prod_rate_S mean: 0.9498, decay_S mean: 0.9442
# Step 29: Converged = False
#
# --- Iteration step: 30 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2678
# prod_rate_S mean: 3.2678, decay_S mean: 3.2528
#
# Simulating gene 1
# prod_rate_U mean: 0.9864, decay_U mean: 1.0015
# prod_rate_S mean: 1.0015, decay_S mean: 1.0154
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1355
# prod_rate_S mean: 1.1355, decay_S mean: 1.1305
#
# Simulating gene 3
# prod_rate_U mean: 0.8146, decay_U mean: 0.8478
# prod_rate_S mean: 0.8478, decay_S mean: 0.8208
#
# Simulating gene 4
# prod_rate_U mean: 3.1087, decay_U mean: 3.1253
# prod_rate_S mean: 3.1253, decay_S mean: 3.1621
#
# Simulating gene 5
# prod_rate_U mean: 1.3786, decay_U mean: 1.3955
# prod_rate_S mean: 1.3955, decay_S mean: 1.3924
#
# Simulating gene 6
# prod_rate_U mean: 0.2879, decay_U mean: 0.2853
# prod_rate_S mean: 0.2853, decay_S mean: 0.2821
#
# Simulating gene 7
# prod_rate_U mean: 0.8201, decay_U mean: 0.8570
# prod_rate_S mean: 0.8570, decay_S mean: 0.8225
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8811
# prod_rate_S mean: 0.8811, decay_S mean: 0.8932
#
# Simulating gene 9
# prod_rate_U mean: 0.9541, decay_U mean: 0.9527
# prod_rate_S mean: 0.9527, decay_S mean: 0.9450
# Step 30: Converged = False
#
# --- Iteration step: 31 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2740
# prod_rate_S mean: 3.2740, decay_S mean: 3.2525
#
# Simulating gene 1
# prod_rate_U mean: 0.9901, decay_U mean: 0.9939
# prod_rate_S mean: 0.9939, decay_S mean: 1.0158
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1359
# prod_rate_S mean: 1.1359, decay_S mean: 1.1312
#
# Simulating gene 3
# prod_rate_U mean: 0.8176, decay_U mean: 0.8455
# prod_rate_S mean: 0.8455, decay_S mean: 0.8203
#
# Simulating gene 4
# prod_rate_U mean: 3.1235, decay_U mean: 3.1308
# prod_rate_S mean: 3.1308, decay_S mean: 3.1613
#
# Simulating gene 5
# prod_rate_U mean: 1.3757, decay_U mean: 1.3944
# prod_rate_S mean: 1.3944, decay_S mean: 1.3924
#
# Simulating gene 6
# prod_rate_U mean: 0.2893, decay_U mean: 0.2852
# prod_rate_S mean: 0.2852, decay_S mean: 0.2817
#
# Simulating gene 7
# prod_rate_U mean: 0.8282, decay_U mean: 0.8569
# prod_rate_S mean: 0.8569, decay_S mean: 0.8220
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8811
# prod_rate_S mean: 0.8811, decay_S mean: 0.8933
#
# Simulating gene 9
# prod_rate_U mean: 0.9478, decay_U mean: 0.9555
# prod_rate_S mean: 0.9555, decay_S mean: 0.9452
# Step 31: Converged = False
#
# --- Iteration step: 32 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2881
# prod_rate_S mean: 3.2881, decay_S mean: 3.2528
#
# Simulating gene 1
# prod_rate_U mean: 0.9896, decay_U mean: 0.9861
# prod_rate_S mean: 0.9861, decay_S mean: 1.0159
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1391
# prod_rate_S mean: 1.1391, decay_S mean: 1.1318
#
# Simulating gene 3
# prod_rate_U mean: 0.8173, decay_U mean: 0.8391
# prod_rate_S mean: 0.8391, decay_S mean: 0.8204
#
# Simulating gene 4
# prod_rate_U mean: 3.1133, decay_U mean: 3.1260
# prod_rate_S mean: 3.1260, decay_S mean: 3.1611
#
# Simulating gene 5
# prod_rate_U mean: 1.3783, decay_U mean: 1.3996
# prod_rate_S mean: 1.3996, decay_S mean: 1.3924
#
# Simulating gene 6
# prod_rate_U mean: 0.2861, decay_U mean: 0.2839
# prod_rate_S mean: 0.2839, decay_S mean: 0.2819
#
# Simulating gene 7
# prod_rate_U mean: 0.8277, decay_U mean: 0.8558
# prod_rate_S mean: 0.8558, decay_S mean: 0.8216
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8764
# prod_rate_S mean: 0.8764, decay_S mean: 0.8932
#
# Simulating gene 9
# prod_rate_U mean: 0.9392, decay_U mean: 0.9573
# prod_rate_S mean: 0.9573, decay_S mean: 0.9450
# Step 32: Converged = False
#
# --- Iteration step: 33 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2865
# prod_rate_S mean: 3.2865, decay_S mean: 3.2528
#
# Simulating gene 1
# prod_rate_U mean: 0.9883, decay_U mean: 0.9797
# prod_rate_S mean: 0.9797, decay_S mean: 1.0152
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1443
# prod_rate_S mean: 1.1443, decay_S mean: 1.1314
#
# Simulating gene 3
# prod_rate_U mean: 0.8162, decay_U mean: 0.8388
# prod_rate_S mean: 0.8388, decay_S mean: 0.8206
#
# Simulating gene 4
# prod_rate_U mean: 3.1263, decay_U mean: 3.1303
# prod_rate_S mean: 3.1303, decay_S mean: 3.1611
#
# Simulating gene 5
# prod_rate_U mean: 1.3775, decay_U mean: 1.3884
# prod_rate_S mean: 1.3884, decay_S mean: 1.3924
#
# Simulating gene 6
# prod_rate_U mean: 0.2880, decay_U mean: 0.2823
# prod_rate_S mean: 0.2823, decay_S mean: 0.2819
#
# Simulating gene 7
# prod_rate_U mean: 0.8359, decay_U mean: 0.8598
# prod_rate_S mean: 0.8598, decay_S mean: 0.8219
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8748
# prod_rate_S mean: 0.8748, decay_S mean: 0.8929
#
# Simulating gene 9
# prod_rate_U mean: 0.9394, decay_U mean: 0.9697
# prod_rate_S mean: 0.9697, decay_S mean: 0.9450
# Step 33: Converged = False
#
# --- Iteration step: 34 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2825
# prod_rate_S mean: 3.2825, decay_S mean: 3.2520
#
# Simulating gene 1
# prod_rate_U mean: 0.9860, decay_U mean: 0.9855
# prod_rate_S mean: 0.9855, decay_S mean: 1.0151
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1491
# prod_rate_S mean: 1.1491, decay_S mean: 1.1317
#
# Simulating gene 3
# prod_rate_U mean: 0.8142, decay_U mean: 0.8318
# prod_rate_S mean: 0.8318, decay_S mean: 0.8210
#
# Simulating gene 4
# prod_rate_U mean: 3.1328, decay_U mean: 3.1292
# prod_rate_S mean: 3.1292, decay_S mean: 3.1607
#
# Simulating gene 5
# prod_rate_U mean: 1.3847, decay_U mean: 1.3954
# prod_rate_S mean: 1.3954, decay_S mean: 1.3924
#
# Simulating gene 6
# prod_rate_U mean: 0.2877, decay_U mean: 0.2822
# prod_rate_S mean: 0.2822, decay_S mean: 0.2820
#
# Simulating gene 7
# prod_rate_U mean: 0.8377, decay_U mean: 0.8547
# prod_rate_S mean: 0.8547, decay_S mean: 0.8225
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8727
# prod_rate_S mean: 0.8727, decay_S mean: 0.8937
#
# Simulating gene 9
# prod_rate_U mean: 0.9482, decay_U mean: 0.9625
# prod_rate_S mean: 0.9625, decay_S mean: 0.9455
# Step 34: Converged = False
#
# --- Iteration step: 35 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2747
# prod_rate_S mean: 3.2747, decay_S mean: 3.2520
#
# Simulating gene 1
# prod_rate_U mean: 0.9856, decay_U mean: 0.9845
# prod_rate_S mean: 0.9845, decay_S mean: 1.0147
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1427
# prod_rate_S mean: 1.1427, decay_S mean: 1.1315
#
# Simulating gene 3
# prod_rate_U mean: 0.8139, decay_U mean: 0.8304
# prod_rate_S mean: 0.8304, decay_S mean: 0.8206
#
# Simulating gene 4
# prod_rate_U mean: 3.1312, decay_U mean: 3.1413
# prod_rate_S mean: 3.1413, decay_S mean: 3.1600
#
# Simulating gene 5
# prod_rate_U mean: 1.3822, decay_U mean: 1.3941
# prod_rate_S mean: 1.3941, decay_S mean: 1.3927
#
# Simulating gene 6
# prod_rate_U mean: 0.2901, decay_U mean: 0.2839
# prod_rate_S mean: 0.2839, decay_S mean: 0.2820
#
# Simulating gene 7
# prod_rate_U mean: 0.8419, decay_U mean: 0.8514
# prod_rate_S mean: 0.8514, decay_S mean: 0.8226
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8666
# prod_rate_S mean: 0.8666, decay_S mean: 0.8945
#
# Simulating gene 9
# prod_rate_U mean: 0.9510, decay_U mean: 0.9564
# prod_rate_S mean: 0.9564, decay_S mean: 0.9454
# Step 35: Converged = False
#
# --- Iteration step: 36 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2729
# prod_rate_S mean: 3.2729, decay_S mean: 3.2516
#
# Simulating gene 1
# prod_rate_U mean: 0.9886, decay_U mean: 0.9905
# prod_rate_S mean: 0.9905, decay_S mean: 1.0150
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1479
# prod_rate_S mean: 1.1479, decay_S mean: 1.1316
#
# Simulating gene 3
# prod_rate_U mean: 0.8165, decay_U mean: 0.8272
# prod_rate_S mean: 0.8272, decay_S mean: 0.8211
#
# Simulating gene 4
# prod_rate_U mean: 3.0929, decay_U mean: 3.1370
# prod_rate_S mean: 3.1370, decay_S mean: 3.1613
#
# Simulating gene 5
# prod_rate_U mean: 1.3755, decay_U mean: 1.4030
# prod_rate_S mean: 1.4030, decay_S mean: 1.3925
#
# Simulating gene 6
# prod_rate_U mean: 0.2909, decay_U mean: 0.2845
# prod_rate_S mean: 0.2845, decay_S mean: 0.2822
#
# Simulating gene 7
# prod_rate_U mean: 0.8286, decay_U mean: 0.8490
# prod_rate_S mean: 0.8490, decay_S mean: 0.8215
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8569
# prod_rate_S mean: 0.8569, decay_S mean: 0.8947
#
# Simulating gene 9
# prod_rate_U mean: 0.9427, decay_U mean: 0.9603
# prod_rate_S mean: 0.9603, decay_S mean: 0.9460
# Step 36: Converged = False
#
# --- Iteration step: 37 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2858
# prod_rate_S mean: 3.2858, decay_S mean: 3.2520
#
# Simulating gene 1
# prod_rate_U mean: 0.9907, decay_U mean: 0.9959
# prod_rate_S mean: 0.9959, decay_S mean: 1.0155
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1483
# prod_rate_S mean: 1.1483, decay_S mean: 1.1317
#
# Simulating gene 3
# prod_rate_U mean: 0.8181, decay_U mean: 0.8389
# prod_rate_S mean: 0.8389, decay_S mean: 0.8215
#
# Simulating gene 4
# prod_rate_U mean: 3.1116, decay_U mean: 3.1256
# prod_rate_S mean: 3.1256, decay_S mean: 3.1613
#
# Simulating gene 5
# prod_rate_U mean: 1.3808, decay_U mean: 1.4059
# prod_rate_S mean: 1.4059, decay_S mean: 1.3925
#
# Simulating gene 6
# prod_rate_U mean: 0.2896, decay_U mean: 0.2827
# prod_rate_S mean: 0.2827, decay_S mean: 0.2823
#
# Simulating gene 7
# prod_rate_U mean: 0.8381, decay_U mean: 0.8583
# prod_rate_S mean: 0.8583, decay_S mean: 0.8215
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8607
# prod_rate_S mean: 0.8607, decay_S mean: 0.8947
#
# Simulating gene 9
# prod_rate_U mean: 0.9380, decay_U mean: 0.9646
# prod_rate_S mean: 0.9646, decay_S mean: 0.9468
# Step 37: Converged = False
#
# --- Iteration step: 38 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2946
# prod_rate_S mean: 3.2946, decay_S mean: 3.2512
#
# Simulating gene 1
# prod_rate_U mean: 0.9851, decay_U mean: 0.9890
# prod_rate_S mean: 0.9890, decay_S mean: 1.0157
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1554
# prod_rate_S mean: 1.1554, decay_S mean: 1.1318
#
# Simulating gene 3
# prod_rate_U mean: 0.8135, decay_U mean: 0.8314
# prod_rate_S mean: 0.8314, decay_S mean: 0.8215
#
# Simulating gene 4
# prod_rate_U mean: 3.1144, decay_U mean: 3.1344
# prod_rate_S mean: 3.1344, decay_S mean: 3.1609
#
# Simulating gene 5
# prod_rate_U mean: 1.3820, decay_U mean: 1.4011
# prod_rate_S mean: 1.4011, decay_S mean: 1.3931
#
# Simulating gene 6
# prod_rate_U mean: 0.2890, decay_U mean: 0.2817
# prod_rate_S mean: 0.2817, decay_S mean: 0.2825
#
# Simulating gene 7
# prod_rate_U mean: 0.8388, decay_U mean: 0.8486
# prod_rate_S mean: 0.8486, decay_S mean: 0.8225
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8591
# prod_rate_S mean: 0.8591, decay_S mean: 0.8949
#
# Simulating gene 9
# prod_rate_U mean: 0.9649, decay_U mean: 0.9705
# prod_rate_S mean: 0.9705, decay_S mean: 0.9474
# Step 38: Converged = False
#
# --- Iteration step: 39 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2726
# prod_rate_S mean: 3.2726, decay_S mean: 3.2501
#
# Simulating gene 1
# prod_rate_U mean: 0.9832, decay_U mean: 0.9849
# prod_rate_S mean: 0.9849, decay_S mean: 1.0154
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1519
# prod_rate_S mean: 1.1519, decay_S mean: 1.1320
#
# Simulating gene 3
# prod_rate_U mean: 0.8119, decay_U mean: 0.8313
# prod_rate_S mean: 0.8313, decay_S mean: 0.8220
#
# Simulating gene 4
# prod_rate_U mean: 3.1219, decay_U mean: 3.1365
# prod_rate_S mean: 3.1365, decay_S mean: 3.1608
#
# Simulating gene 5
# prod_rate_U mean: 1.3772, decay_U mean: 1.3993
# prod_rate_S mean: 1.3993, decay_S mean: 1.3933
#
# Simulating gene 6
# prod_rate_U mean: 0.2880, decay_U mean: 0.2875
# prod_rate_S mean: 0.2875, decay_S mean: 0.2824
#
# Simulating gene 7
# prod_rate_U mean: 0.8413, decay_U mean: 0.8406
# prod_rate_S mean: 0.8406, decay_S mean: 0.8225
#
# Simulating gene 8
# prod_rate_U mean: 0.8790, decay_U mean: 0.8638
# prod_rate_S mean: 0.8638, decay_S mean: 0.8948
#
# Simulating gene 9
# prod_rate_U mean: 0.9690, decay_U mean: 0.9698
# prod_rate_S mean: 0.9698, decay_S mean: 0.9473
# Step 39: Converged = False
#
# --- Iteration step: 40 ---
#
# Simulating gene 0
# prod_rate_U mean: 3.3140, decay_U mean: 3.2675
# prod_rate_S mean: 3.2675, decay_S mean: 3.2499
#
# Simulating gene 1
# prod_rate_U mean: 0.9850, decay_U mean: 0.9809
# prod_rate_S mean: 0.9809, decay_S mean: 1.0149
#
# Simulating gene 2
# prod_rate_U mean: 1.1270, decay_U mean: 1.1566
# prod_rate_S mean: 1.1566, decay_S mean: 1.1323
#
# Simulating gene 3
# prod_rate_U mean: 0.8134, decay_U mean: 0.8278
# prod_rate_S mean: 0.8278, decay_S mean: 0.8219
#
# Simulating gene 4
# ...
#
# Simulating gene 9
# prod_rate_U mean: 1.6386, decay_U mean: 1.6797
# prod_rate_S mean: 1.6797, decay_S mean: 1.7252
# Step 1297: Converged = False
#
# --- Iteration step: 1298 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0245
# prod_rate_S mean: 2.0245, decay_S mean: 2.1782
#
# Simulating gene 1
# prod_rate_U mean: 0.5762, decay_U mean: 0.5743
# prod_rate_S mean: 0.5743, decay_S mean: 0.6412
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9936
# prod_rate_S mean: 0.9936, decay_S mean: 1.0368
#
# Simulating gene 3
# prod_rate_U mean: 0.4758, decay_U mean: 0.4722
# prod_rate_S mean: 0.4722, decay_S mean: 0.5272
#
# Simulating gene 4
# prod_rate_U mean: 4.4229, decay_U mean: 4.4370
# prod_rate_S mean: 4.4370, decay_S mean: 4.4427
#
# Simulating gene 5
# prod_rate_U mean: 2.0790, decay_U mean: 2.0773
# prod_rate_S mean: 2.0773, decay_S mean: 2.0808
#
# Simulating gene 6
# prod_rate_U mean: 0.4632, decay_U mean: 0.4493
# prod_rate_S mean: 0.4493, decay_S mean: 0.4650
#
# Simulating gene 7
# prod_rate_U mean: 1.3673, decay_U mean: 1.3750
# prod_rate_S mean: 1.3750, decay_S mean: 1.2541
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9038
# prod_rate_S mean: 0.9038, decay_S mean: 1.1946
#
# Simulating gene 9
# prod_rate_U mean: 1.6360, decay_U mean: 1.6782
# prod_rate_S mean: 1.6782, decay_S mean: 1.7253
# Step 1298: Converged = False
#
# --- Iteration step: 1299 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0282
# prod_rate_S mean: 2.0282, decay_S mean: 2.1779
#
# Simulating gene 1
# prod_rate_U mean: 0.5761, decay_U mean: 0.5742
# prod_rate_S mean: 0.5742, decay_S mean: 0.6410
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9944
# prod_rate_S mean: 0.9944, decay_S mean: 1.0368
#
# Simulating gene 3
# prod_rate_U mean: 0.4758, decay_U mean: 0.4723
# prod_rate_S mean: 0.4723, decay_S mean: 0.5271
#
# Simulating gene 4
# prod_rate_U mean: 4.4293, decay_U mean: 4.4340
# prod_rate_S mean: 4.4340, decay_S mean: 4.4424
#
# Simulating gene 5
# prod_rate_U mean: 2.0802, decay_U mean: 2.0803
# prod_rate_S mean: 2.0803, decay_S mean: 2.0809
#
# Simulating gene 6
# prod_rate_U mean: 0.4636, decay_U mean: 0.4488
# prod_rate_S mean: 0.4488, decay_S mean: 0.4650
#
# Simulating gene 7
# prod_rate_U mean: 1.3695, decay_U mean: 1.3758
# prod_rate_S mean: 1.3758, decay_S mean: 1.2542
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9050
# prod_rate_S mean: 0.9050, decay_S mean: 1.1939
#
# Simulating gene 9
# prod_rate_U mean: 1.6349, decay_U mean: 1.6767
# prod_rate_S mean: 1.6767, decay_S mean: 1.7249
# Step 1299: Converged = False
#
# --- Iteration step: 1300 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0281
# prod_rate_S mean: 2.0281, decay_S mean: 2.1778
#
# Simulating gene 1
# prod_rate_U mean: 0.5763, decay_U mean: 0.5756
# prod_rate_S mean: 0.5756, decay_S mean: 0.6408
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9941
# prod_rate_S mean: 0.9941, decay_S mean: 1.0367
#
# Simulating gene 3
# prod_rate_U mean: 0.4759, decay_U mean: 0.4709
# prod_rate_S mean: 0.4709, decay_S mean: 0.5269
#
# Simulating gene 4
# prod_rate_U mean: 4.4323, decay_U mean: 4.4370
# prod_rate_S mean: 4.4370, decay_S mean: 4.4422
#
# Simulating gene 5
# prod_rate_U mean: 2.0764, decay_U mean: 2.0825
# prod_rate_S mean: 2.0825, decay_S mean: 2.0808
#
# Simulating gene 6
# prod_rate_U mean: 0.4630, decay_U mean: 0.4483
# prod_rate_S mean: 0.4483, decay_S mean: 0.4649
#
# Simulating gene 7
# prod_rate_U mean: 1.3695, decay_U mean: 1.3763
# prod_rate_S mean: 1.3763, decay_S mean: 1.2543
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9069
# prod_rate_S mean: 0.9069, decay_S mean: 1.1933
#
# Simulating gene 9
# prod_rate_U mean: 1.6340, decay_U mean: 1.6760
# prod_rate_S mean: 1.6760, decay_S mean: 1.7251
# Step 1300: Converged = False
#
# --- Iteration step: 1301 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0284
# prod_rate_S mean: 2.0284, decay_S mean: 2.1774
#
# Simulating gene 1
# prod_rate_U mean: 0.5764, decay_U mean: 0.5767
# prod_rate_S mean: 0.5767, decay_S mean: 0.6407
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9931
# prod_rate_S mean: 0.9931, decay_S mean: 1.0364
#
# Simulating gene 3
# prod_rate_U mean: 0.4760, decay_U mean: 0.4708
# prod_rate_S mean: 0.4708, decay_S mean: 0.5268
#
# Simulating gene 4
# prod_rate_U mean: 4.4334, decay_U mean: 4.4294
# prod_rate_S mean: 4.4294, decay_S mean: 4.4417
#
# Simulating gene 5
# prod_rate_U mean: 2.0753, decay_U mean: 2.0800
# prod_rate_S mean: 2.0800, decay_S mean: 2.0808
#
# Simulating gene 6
# prod_rate_U mean: 0.4629, decay_U mean: 0.4481
# prod_rate_S mean: 0.4481, decay_S mean: 0.4649
#
# Simulating gene 7
# prod_rate_U mean: 1.3696, decay_U mean: 1.3765
# prod_rate_S mean: 1.3765, decay_S mean: 1.2546
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9071
# prod_rate_S mean: 0.9071, decay_S mean: 1.1927
#
# Simulating gene 9
# prod_rate_U mean: 1.6328, decay_U mean: 1.6748
# prod_rate_S mean: 1.6748, decay_S mean: 1.7249
# Step 1301: Converged = False
#
# --- Iteration step: 1302 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0288
# prod_rate_S mean: 2.0288, decay_S mean: 2.1772
#
# Simulating gene 1
# prod_rate_U mean: 0.5748, decay_U mean: 0.5781
# prod_rate_S mean: 0.5781, decay_S mean: 0.6406
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9920
# prod_rate_S mean: 0.9920, decay_S mean: 1.0363
#
# Simulating gene 3
# prod_rate_U mean: 0.4747, decay_U mean: 0.4707
# prod_rate_S mean: 0.4707, decay_S mean: 0.5266
#
# Simulating gene 4
# prod_rate_U mean: 4.4423, decay_U mean: 4.4276
# prod_rate_S mean: 4.4276, decay_S mean: 4.4415
#
# Simulating gene 5
# prod_rate_U mean: 2.0767, decay_U mean: 2.0794
# prod_rate_S mean: 2.0794, decay_S mean: 2.0809
#
# Simulating gene 6
# prod_rate_U mean: 0.4629, decay_U mean: 0.4479
# prod_rate_S mean: 0.4479, decay_S mean: 0.4649
#
# Simulating gene 7
# prod_rate_U mean: 1.3728, decay_U mean: 1.3765
# prod_rate_S mean: 1.3765, decay_S mean: 1.2548
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9098
# prod_rate_S mean: 0.9098, decay_S mean: 1.1921
#
# Simulating gene 9
# prod_rate_U mean: 1.6323, decay_U mean: 1.6742
# prod_rate_S mean: 1.6742, decay_S mean: 1.7249
# Step 1302: Converged = False
#
# --- Iteration step: 1303 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0246
# prod_rate_S mean: 2.0246, decay_S mean: 2.1771
#
# Simulating gene 1
# prod_rate_U mean: 0.5741, decay_U mean: 0.5792
# prod_rate_S mean: 0.5792, decay_S mean: 0.6405
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9924
# prod_rate_S mean: 0.9924, decay_S mean: 1.0361
#
# Simulating gene 3
# prod_rate_U mean: 0.4741, decay_U mean: 0.4687
# prod_rate_S mean: 0.4687, decay_S mean: 0.5263
#
# Simulating gene 4
# prod_rate_U mean: 4.4423, decay_U mean: 4.4307
# prod_rate_S mean: 4.4307, decay_S mean: 4.4416
#
# Simulating gene 5
# prod_rate_U mean: 2.0780, decay_U mean: 2.0790
# prod_rate_S mean: 2.0790, decay_S mean: 2.0809
#
# Simulating gene 6
# prod_rate_U mean: 0.4631, decay_U mean: 0.4478
# prod_rate_S mean: 0.4478, decay_S mean: 0.4648
#
# Simulating gene 7
# prod_rate_U mean: 1.3716, decay_U mean: 1.3774
# prod_rate_S mean: 1.3774, decay_S mean: 1.2550
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9115
# prod_rate_S mean: 0.9115, decay_S mean: 1.1915
#
# Simulating gene 9
# prod_rate_U mean: 1.6308, decay_U mean: 1.6760
# prod_rate_S mean: 1.6760, decay_S mean: 1.7250
# Step 1303: Converged = False
#
# --- Iteration step: 1304 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0229
# prod_rate_S mean: 2.0229, decay_S mean: 2.1768
#
# Simulating gene 1
# prod_rate_U mean: 0.5741, decay_U mean: 0.5777
# prod_rate_S mean: 0.5777, decay_S mean: 0.6403
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9912
# prod_rate_S mean: 0.9912, decay_S mean: 1.0360
#
# Simulating gene 3
# prod_rate_U mean: 0.4741, decay_U mean: 0.4695
# prod_rate_S mean: 0.4695, decay_S mean: 0.5261
#
# Simulating gene 4
# prod_rate_U mean: 4.4372, decay_U mean: 4.4334
# prod_rate_S mean: 4.4334, decay_S mean: 4.4416
#
# Simulating gene 5
# prod_rate_U mean: 2.0796, decay_U mean: 2.0799
# prod_rate_S mean: 2.0799, decay_S mean: 2.0810
#
# Simulating gene 6
# prod_rate_U mean: 0.4633, decay_U mean: 0.4474
# prod_rate_S mean: 0.4474, decay_S mean: 0.4647
#
# Simulating gene 7
# prod_rate_U mean: 1.3707, decay_U mean: 1.3753
# prod_rate_S mean: 1.3753, decay_S mean: 1.2553
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9073
# prod_rate_S mean: 0.9073, decay_S mean: 1.1910
#
# Simulating gene 9
# prod_rate_U mean: 1.6330, decay_U mean: 1.6771
# prod_rate_S mean: 1.6771, decay_S mean: 1.7249
# Step 1304: Converged = True
# Convergence reached at step 1304, total steps recorded: 1306.0
# Resume after convergence: True
#
# --- Iteration step: 1305 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0229
# prod_rate_S mean: 2.0229, decay_S mean: 2.1763
#
# Simulating gene 1
# prod_rate_U mean: 0.5741, decay_U mean: 0.5777
# prod_rate_S mean: 0.5777, decay_S mean: 0.6401
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9904
# prod_rate_S mean: 0.9904, decay_S mean: 1.0362
#
# Simulating gene 3
# prod_rate_U mean: 0.4741, decay_U mean: 0.4700
# prod_rate_S mean: 0.4700, decay_S mean: 0.5260
#
# Simulating gene 4
# prod_rate_U mean: 4.4311, decay_U mean: 4.4364
# prod_rate_S mean: 4.4364, decay_S mean: 4.4416
#
# Simulating gene 5
# prod_rate_U mean: 2.0803, decay_U mean: 2.0806
# prod_rate_S mean: 2.0806, decay_S mean: 2.0809
#
# Simulating gene 6
# prod_rate_U mean: 0.4628, decay_U mean: 0.4480
# prod_rate_S mean: 0.4480, decay_S mean: 0.4647
#
# Simulating gene 7
# prod_rate_U mean: 1.3682, decay_U mean: 1.3729
# prod_rate_S mean: 1.3729, decay_S mean: 1.2557
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9068
# prod_rate_S mean: 0.9068, decay_S mean: 1.1904
#
# Simulating gene 9
# prod_rate_U mean: 1.6339, decay_U mean: 1.6761
# prod_rate_S mean: 1.6761, decay_S mean: 1.7246
# Step 1305: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1306 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0229
# prod_rate_S mean: 2.0229, decay_S mean: 2.1758
#
# Simulating gene 1
# prod_rate_U mean: 0.5735, decay_U mean: 0.5777
# prod_rate_S mean: 0.5777, decay_S mean: 0.6399
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9908
# prod_rate_S mean: 0.9908, decay_S mean: 1.0363
#
# Simulating gene 3
# prod_rate_U mean: 0.4736, decay_U mean: 0.4714
# prod_rate_S mean: 0.4714, decay_S mean: 0.5259
#
# Simulating gene 4
# prod_rate_U mean: 4.4272, decay_U mean: 4.4377
# prod_rate_S mean: 4.4377, decay_S mean: 4.4413
#
# Simulating gene 5
# prod_rate_U mean: 2.0806, decay_U mean: 2.0781
# prod_rate_S mean: 2.0781, decay_S mean: 2.0807
#
# Simulating gene 6
# prod_rate_U mean: 0.4631, decay_U mean: 0.4481
# prod_rate_S mean: 0.4481, decay_S mean: 0.4647
#
# Simulating gene 7
# prod_rate_U mean: 1.3653, decay_U mean: 1.3727
# prod_rate_S mean: 1.3727, decay_S mean: 1.2559
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9091
# prod_rate_S mean: 0.9091, decay_S mean: 1.1898
#
# Simulating gene 9
# prod_rate_U mean: 1.6361, decay_U mean: 1.6748
# prod_rate_S mean: 1.6748, decay_S mean: 1.7248
# Step 1306: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1307 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0214
# prod_rate_S mean: 2.0214, decay_S mean: 2.1757
#
# Simulating gene 1
# prod_rate_U mean: 0.5735, decay_U mean: 0.5795
# prod_rate_S mean: 0.5795, decay_S mean: 0.6398
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9912
# prod_rate_S mean: 0.9912, decay_S mean: 1.0361
#
# Simulating gene 3
# prod_rate_U mean: 0.4737, decay_U mean: 0.4730
# prod_rate_S mean: 0.4730, decay_S mean: 0.5258
#
# Simulating gene 4
# prod_rate_U mean: 4.4232, decay_U mean: 4.4383
# prod_rate_S mean: 4.4383, decay_S mean: 4.4413
#
# Simulating gene 5
# prod_rate_U mean: 2.0809, decay_U mean: 2.0794
# prod_rate_S mean: 2.0794, decay_S mean: 2.0807
#
# Simulating gene 6
# prod_rate_U mean: 0.4633, decay_U mean: 0.4486
# prod_rate_S mean: 0.4486, decay_S mean: 0.4647
#
# Simulating gene 7
# prod_rate_U mean: 1.3646, decay_U mean: 1.3755
# prod_rate_S mean: 1.3755, decay_S mean: 1.2562
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9087
# prod_rate_S mean: 0.9087, decay_S mean: 1.1891
#
# Simulating gene 9
# prod_rate_U mean: 1.6357, decay_U mean: 1.6763
# prod_rate_S mean: 1.6763, decay_S mean: 1.7246
# Step 1307: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1308 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0213
# prod_rate_S mean: 2.0213, decay_S mean: 2.1754
#
# Simulating gene 1
# prod_rate_U mean: 0.5729, decay_U mean: 0.5786
# prod_rate_S mean: 0.5786, decay_S mean: 0.6397
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9933
# prod_rate_S mean: 0.9933, decay_S mean: 1.0360
#
# Simulating gene 3
# prod_rate_U mean: 0.4732, decay_U mean: 0.4735
# prod_rate_S mean: 0.4735, decay_S mean: 0.5257
#
# Simulating gene 4
# prod_rate_U mean: 4.4298, decay_U mean: 4.4387
# prod_rate_S mean: 4.4387, decay_S mean: 4.4414
#
# Simulating gene 5
# prod_rate_U mean: 2.0793, decay_U mean: 2.0800
# prod_rate_S mean: 2.0800, decay_S mean: 2.0808
#
# Simulating gene 6
# prod_rate_U mean: 0.4634, decay_U mean: 0.4489
# prod_rate_S mean: 0.4489, decay_S mean: 0.4646
#
# Simulating gene 7
# prod_rate_U mean: 1.3669, decay_U mean: 1.3748
# prod_rate_S mean: 1.3748, decay_S mean: 1.2563
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9099
# prod_rate_S mean: 0.9099, decay_S mean: 1.1886
#
# Simulating gene 9
# prod_rate_U mean: 1.6360, decay_U mean: 1.6762
# prod_rate_S mean: 1.6762, decay_S mean: 1.7244
# Step 1308: Converged = True
# Resume after convergence: True
#
# --- Iteration step: 1309 ---
#
# Simulating gene 0
# prod_rate_U mean: 2.0000, decay_U mean: 2.0197
# prod_rate_S mean: 2.0197, decay_S mean: 2.1754
#
# Simulating gene 1
# prod_rate_U mean: 0.5733, decay_U mean: 0.5771
# prod_rate_S mean: 0.5771, decay_S mean: 0.6395
#
# Simulating gene 2
# prod_rate_U mean: 1.0000, decay_U mean: 0.9929
# prod_rate_S mean: 0.9929, decay_S mean: 1.0361
#
# Simulating gene 3
# prod_rate_U mean: 0.4735, decay_U mean: 0.4719
# prod_rate_S mean: 0.4719, decay_S mean: 0.5256
#
# Simulating gene 4
# prod_rate_U mean: 4.4286, decay_U mean: 4.4352
# prod_rate_S mean: 4.4352, decay_S mean: 4.4412
#
# Simulating gene 5
# prod_rate_U mean: 2.0806, decay_U mean: 2.0802
# prod_rate_S mean: 2.0802, decay_S mean: 2.0809
#
# Simulating gene 6
# prod_rate_U mean: 0.4629, decay_U mean: 0.4490
# prod_rate_S mean: 0.4490, decay_S mean: 0.4646
#
# Simulating gene 7
# prod_rate_U mean: 1.3682, decay_U mean: 1.3740
# prod_rate_S mean: 1.3740, decay_S mean: 1.2566
#
# Simulating gene 8
# prod_rate_U mean: 0.9000, decay_U mean: 0.9067
# prod_rate_S mean: 0.9067, decay_S mean: 1.1881
#
# Simulating gene 9
# prod_rate_U mean: 1.6386, decay_U mean: 1.6761
# prod_rate_S mean: 1.6761, decay_S mean: 1.7242
# Step 1309: Converged = True
# Resume after convergence: False
# === Finished bin 3 in 62.99 seconds ===
# [[4.59263967 4.36830012 4.4444543  ... 5.12585331 4.87713303 4.66373155]
#  [1.40275878 1.2311525  1.40329959 ... 1.34248111 1.23760602 1.53637101]
#  [1.41413451 1.94187341 1.51277    ... 0.49362823 0.65528875 0.42130028]
#  ...
#  [0.99558771 0.99628321 1.25292769 ... 0.65091546 0.5694844  1.40293439]
#  [1.12113189 0.76831376 1.05841978 ... 3.76202321 3.45902935 4.03045216]
#  [0.54696649 1.14904783 1.25896822 ... 2.31556978 1.19749705 1.64030769]]
# (10, 1500)
# exprU_clean shape: (10, 1500)
# exprS_clean shape: (10, 1500)
# Row 0 of exprU_clean has 1500 columns
# Row 1 of exprU_clean has 1500 columns
# Row 2 of exprU_clean has 1500 columns
# Row 3 of exprU_clean has 1500 columns
# Row 4 of exprU_clean has 1500 columns
# Row 5 of exprU_clean has 1500 columns
# Row 6 of exprU_clean has 1500 columns
# Row 7 of exprU_clean has 1500 columns
# Row 8 of exprU_clean has 1500 columns
# Row 9 of exprU_clean has 1500 columns
# Row 0 of exprS_clean has 1500 columns
# Row 1 of exprS_clean has 1500 columns
# Row 2 of exprS_clean has 1500 columns
# Row 3 of exprS_clean has 1500 columns
# Row 4 of exprS_clean has 1500 columns
# Row 5 of exprS_clean has 1500 columns
# Row 6 of exprS_clean has 1500 columns
# Row 7 of exprS_clean has 1500 columns
# Row 8 of exprS_clean has 1500 columns
# Row 9 of exprS_clean has 1500 columns

# %%
exprTotal_clean = exprU_clean + exprS_clean
print(f"exprTotal_clean shape: {exprTotal_clean.shape}")
np.savetxt('exprTotal_clean.txt', exprTotal_clean, delimiter=' ', fmt='%f')
# Out:
# exprTotal_clean shape: (10, 1500)

# %% [markdown]
# # Compute pseudotimes
#
# First create the txt file from csv to find the pseudotimes

# %%
# import os

# def csv_to_txt(input_csv, output_folder="data/output"):
#     os.makedirs(output_folder, exist_ok=True)
#     output_txt = os.path.join(output_folder, os.path.basename(input_csv).replace(".csv", ".txt"))

#     with open(input_csv, 'r') as csv_file, open(output_txt, 'w') as txt_file:
#         for line in csv_file:
#             txt_file.write(line.replace(',', ' '))

#     print(f"Saved to {output_txt}")

# # Example usage in Jupyter Notebook
# input_csv = "--"  # Change this as needed
# csv_to_txt(input_csv)

#questions for wenjun: 
#what is the meaning of all of these instances of simulated csvs? are they all for the same grn and am i supposed to simulate all of them?
#for some reason when I transform the csv to txt, it's missing a single column header due to the nature of the data  
#help me figure out wt is going on w sergio

# %%
# data = np.loadtxt( "data_linear.txt" )

#data = np.load("data_bifurcate.npy")
def analyze_txt(input_txt):
    with open(input_txt, 'r') as txt_file:
        expected_columns = None
        for i, line in enumerate(txt_file):
            columns = line.strip().split()  # Split line into columns based on spaces
            num_columns = len(columns)
            
            if expected_columns is None:
                expected_columns = num_columns  # Set initial expected columns
            
            if num_columns != expected_columns:
                print(f"Column mismatch at row {i}: expected {expected_columns}, found {num_columns}")
            
            print(f"Row {i}: {num_columns} columns")  # Print column count for each row

# Example usage
input_txt = 'exprTotal_clean.txt'  # Replace with your actual TXT file path
analyze_txt(input_txt)

data = np.loadtxt( "exprTotal_clean.txt" )
# Out:
# Row 0: 1500 columns
# Row 1: 1500 columns
# Row 2: 1500 columns
# Row 3: 1500 columns
# Row 4: 1500 columns
# Row 5: 1500 columns
# Row 6: 1500 columns
# Row 7: 1500 columns
# Row 8: 1500 columns
# Row 9: 1500 columns

# %%
data.shape
# Out:
# (10, 1500)

# %%
plt.rcParams["figure.figsize"] = (5,5)
        # PCAs:
from sklearn.decomposition import PCA
plt.rcParams["font.size"] = 24
pca = PCA()
Xt_all = pca.fit_transform(np.log2(data.T+1) ) 
plt.scatter(Xt_all[:,0],Xt_all[:,1], c=range(Xt_all.shape[0]) )
#         for j in range(Nt):
#             idx = range(num_cells_per_time*j, num_cells_per_time*(j+1))
#             plt.plot(Xt_all[idx,0],Xt_all[idx,1],'o-')
       
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Data')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        
plt.show()
# Out:
# /var/folders/6s/mn0cx1qn7b901qdgrbh6z_hm0000gp/T/ipykernel_23008/369344071.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
Xt_all.shape
# Out:
# (1500, 10)

# %%
# from sklearn.cluster import KMeans
from anndata import AnnData
# num_clusters = 9  # Set the number of clusters you want for KMeans

# # Apply KMeans clustering
# kmeans = KMeans(n_clusters=num_clusters, random_state=42)
# cluster_labels = kmeans.fit_predict(Xt_all)  # Using PCA components for clustering
cluster_labels = np.zeros( (1500) )
cluster_labels[0:300] = 0
cluster_labels[300:600] = 1
cluster_labels[600:900] = 2
cluster_labels[900:1200] = 3
cluster_labels[1200:1500] = 4
cluster_labels=np.int8(cluster_labels)

# %%
cluster_labels[0]
# Out:
# 0

# %% [markdown]
# Create anndata obj

# %%
num_cells = data.shape[1]
num_genes = data.shape[0]
ad = AnnData(data.T)
ad.obsm["X_umap"] = Xt_all[:,0:2]
ad.obs["celltype"] = cluster_labels

# %%
cluster_labels
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int8)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
custom_xlim = (-12, 12)
custom_ylim = (-12, 12)

slingshot = Slingshot(ad, celltype_key="celltype", obsm_key="X_umap", start_node=0, debug_level='verbose')


slingshot.fit(num_epochs=1, debug_axes=axes)

# Adjust legend size
for ax in axes.flatten():
    legend = ax.get_legend()
    if legend:
        legend.set_title(legend.get_title().get_text(), prop={'size': 10})  # Reduce legend title size
        for text in legend.get_texts():
            text.set_fontsize(8)  # Reduce legend item text size

plt.tight_layout()  # Optional: improves spacing
plt.savefig("experiments_final/num_4/slingshot_output.png", dpi=300)  # Saves the figure as a PNG with high resolution
# Out:
# /Users/JenChen/Desktop/otvelo/researchy/lib/python3.9/site-packages/pyslingshot/util.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isint(cluster_labels[0]):
# Lineages: [Lineage[0, 1, 3, 2], Lineage[0, 4]]
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/JenChen/Desktop/otvelo/researchy/lib/python3.9/site-packages/pyslingshot/slingshot.py:333: RuntimeWarning: invalid value encountered in divide
#   cell_weights = z_prime / np.nanmax(z_prime, axis=1, keepdims=True) #rowMins(D) / D
# Reversing from leaf to root
# Averaging branch @0 with lineages: [0, 1] [<pcurvepy2.pcurve.PrincipalCurve object at 0x7fa704c9cf40>, <pcurvepy2.pcurve.PrincipalCurve object at 0x7fa704ca51f0>]
# Shrinking branch @0 with curves: [<pcurvepy2.pcurve.PrincipalCurve object at 0x7fa704c9cf40>, <pcurvepy2.pcurve.PrincipalCurve object at 0x7fa704ca51f0>]
# 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]

# %%
pseudotime = slingshot.unified_pseudotime
ad.obs["pseudotime"] = slingshot.unified_pseudotime

print(type(slingshot.unified_pseudotime))  # Check the object type
print(slingshot.unified_pseudotime.shape)  # Check its dimensions
print(slingshot.unified_pseudotime[:5])    # Print first few values
# Out:
# <class 'numpy.ndarray'>
# (1500,)
# [5.62050406e-16 4.44089210e-16 8.88372415e-02 3.05311332e-16
#  7.39505225e-02]

# %% [markdown]
# Add splicing data to anndata object also

# %%
spliced_data = np.loadtxt("exprS_clean.txt") #spliced RNA
unspliced_data = np.loadtxt("exprU_clean.txt") #unspliced RNA

# Ensure the shape matches adata.X (genes x cells)
print(spliced_data.shape)  # Should be (num_genes, num_cells)
print(unspliced_data.shape)  # Should be (num_genes, num_cells)
print(ad.layers.keys())
# Transpose if necessary (AnnData assumes cells x genes)
if spliced_data.shape[1] == ad.n_obs and spliced_data.shape[0] == ad.n_vars:
    ad.layers["spliced"] = spliced_data.T  # Ensure it aligns with AnnData structure
    print('done w spliced')
else:
    raise ValueError("Shape mismatch! Check if genes and cells are correctly aligned.")

if unspliced_data.shape[1] == ad.n_obs and unspliced_data.shape[0] == ad.n_vars:
    ad.layers["unspliced"] = unspliced_data.T  # Ensure it aligns with AnnData structure
    print('done w unspliced')
else:
    raise ValueError("Shape mismatch! Check if genes and cells are correctly aligned.")

# Print splicing data info
print("spliced data shape:", ad.layers["spliced"].shape)
print("spliced data (first 5 genes, first 5 cells):\n", ad.layers["spliced"][:5, :5])
print("unspliced data shape:", ad.layers["unspliced"].shape)
print("unspliced data (first 5 genes, first 5 cells):\n", ad.layers["unspliced"][:5, :5])

# Print pseudotime data info
print("Pseudotime data shape:", ad.obs["pseudotime"].shape)
print("Pseudotime values (first 10 cells):\n", ad.obs["pseudotime"].head(10))
print(ad.layers.keys())
ad.write("custom_ad.h5ad")
# Out:
# (10, 1500)
# (10, 1500)
# KeysView(Layers with keys: )
# done w spliced
# done w unspliced
# spliced data shape: (1500, 10)
# spliced data (first 5 genes, first 5 cells):
#  [[15.913581  4.924964  5.73958   4.291112 15.878414]
#  [16.256201  5.064409  5.804364  4.445317 15.313224]
#  [15.449223  4.833075  5.663909  3.783048 17.055377]
#  [17.084971  4.93098   5.793115  4.07918  15.913637]
#  [15.759801  4.859739  5.69863   4.172937 15.377757]]
# unspliced data shape: (1500, 10)
# unspliced data (first 5 genes, first 5 cells):
#  [[4.59264  1.402759 1.414135 1.042585 4.150396]
#  [4.3683   1.231152 1.941873 1.062667 3.815616]
#  [4.444454 1.4033   1.51277  1.369991 4.140331]
#  [4.283496 1.34785  1.383966 1.292664 3.167237]
#  [4.390031 1.265335 1.448657 0.957012 3.829073]]
# Pseudotime data shape: (1500,)
# Pseudotime values (first 10 cells):
#  0    5.620504e-16
# 1    4.440892e-16
# 2    8.883724e-02
# 3    3.053113e-16
# 4    7.395052e-02
# 5    3.053113e-16
# 6    4.787837e-16
# 7    1.343403e-01
# 8    2.799619e-02
# 9    1.021856e-01
# Name: pseudotime, dtype: float64
# KeysView(Layers with keys: spliced, unspliced)

# %%
plt.rcParams["figure.figsize"] = (6,6)
        # PCAs:
from sklearn.decomposition import PCA
plt.rcParams["font.size"] = 24
pca = PCA()
Xt_all = pca.fit_transform(np.log2(data.T+1) ) 
# sc = plt.scatter(Xt_all[:,0],Xt_all[:,1], c=pseudotime )
sc = plt.scatter(Xt_all[:, 0], Xt_all[:, 1], c=pseudotime, cmap='viridis', s=20)

#         for j in range(Nt):
#             idx = range(num_cells_per_time*j, num_cells_per_time*(j+1))
#             plt.plot(Xt_all[idx,0],Xt_all[idx,1],'o-')
#how to keep track of which cell is corr to which branch

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Pseudotime PCA')

# Add a colorbar to show pseudotime scale
cbar = plt.colorbar(sc)
cbar.set_label('Pseudotime')

plt.tight_layout()
plt.savefig("experiments_final/num_4/pseudotime_pca.png", dpi=300)  # Saves as a high-resolution PNG
plt.show()
